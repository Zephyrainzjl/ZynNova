# %% [markdown]
# # Installation and API discovery
#
# This notebook verifies the installed package and shows the public discovery APIs.

# %%
import zynnova
print('ZynNova:', zynnova.__version__)
print('Structure types:', zynnova.StructureData, zynnova.GraphData)

# %%
from zynnova.structure.common import native_available
print('Native C++ structure backend:', native_available())

# %%
try:
    from zynnova.ml import list_models
except ImportError as exc:
    print('Install zynnova[ml-all] for model discovery:', exc)
else:
    print('Models:', list_models())
