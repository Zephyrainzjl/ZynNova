# %% [markdown]
# # `zynnova.ml.encode_polymer_generation_sequence`
#
# Public API notebook for **encode_polymer_generation_sequence**. This page only uses the supported public import path and intentionally omits internal implementation details.
#
# **Purpose:** Public function `encode_polymer_generation_sequence`.

# %% [markdown]
# ## Installation
#
# Recommended installation for this API: `pip install 'zynnova[ml-generation]'`.
#
# Run this notebook from an environment where ZynNova is installed. Expensive downloads, training, visualization, and simulations are disabled by default.

# %%
try:
    from zynnova.ml import encode_polymer_generation_sequence as API
except ImportError as exc:
    API = None
    print('Optional dependency or installation is missing:', exc)
else:
    print('Imported: zynnova.ml.encode_polymer_generation_sequence')

# %% [markdown]
# ## Signature
#
# ```python
# encode_polymer_generation_sequence(psmiles: str, representation: GenerationRepresentation) -> str
# ```
#
# | Parameter | Type | Default | Required |
# |---|---|---|---|
# | `psmiles` | `str` | `-` | yes |
# | `representation` | `GenerationRepresentation` | `-` | yes |

# %%
import inspect

if API is not None:
    try:
        print(inspect.signature(API))
    except (TypeError, ValueError):
        print('This public object has no callable signature.')
    summary = (getattr(API, '__doc__', None) or '').strip()
    print(summary.split('\n\n', 1)[0] if summary else 'No public docstring.')

# %% [markdown]
# ## Minimal public usage
#
# The example below stays on the public API surface.

# %%
RUN_EXAMPLE = False  # Set True after replacing placeholders with your data.

if API is not None and RUN_EXAMPLE:
    result = API(...)  # Signature: encode_polymer_generation_sequence(psmiles: str, representation: GenerationRepresentation) -> str
    print(result)

# %% [markdown]
# ## Expected behavior and common failures
#
# - `ValueError(f'unsupported polymer generation representation: {representation!r}')`
#
# For dataset downloads, model training, molecular dynamics, and external engines, first test with a small input and an explicit output directory.
