# %% [markdown]
# # `zynnova.ml.PolyPredictionTrainConfig`
#
# Public API notebook for **PolyPredictionTrainConfig**. This page only uses the supported public import path and intentionally omits internal implementation details.
#
# **Purpose:** Public dataclass `PolyPredictionTrainConfig`.

# %% [markdown]
# ## Installation
#
# Recommended installation for this API: `pip install 'zynnova[ml-generation]'`.
#
# Run this notebook from an environment where ZynNova is installed. Expensive downloads, training, visualization, and simulations are disabled by default.

# %%
try:
    from zynnova.ml import PolyPredictionTrainConfig as API
except ImportError as exc:
    API = None
    print('Optional dependency or installation is missing:', exc)
else:
    print('Imported: zynnova.ml.PolyPredictionTrainConfig')

# %% [markdown]
# ## Signature
#
# ```python
# PolyPredictionTrainConfig(epochs: int = 300, learning_rate: float = 0.0002, weight_decay: float = 0.0001, gradient_clip_norm: float | None = 5.0, physics_loss_weight: float = 0.08, entropy_consistency_weight: float = 0.2, patience: int = 35, min_delta: float = 1e-05, device: str = 'auto', dtype: str = 'float32', seed: int = 42, deterministic: bool = False, workspace_root: str | Path | None = None, run_name: str | None = None)
# ```
#
# | Parameter | Type | Default | Required |
# |---|---|---|---|
# | `epochs` | `int` | `300` | no |
# | `learning_rate` | `float` | `0.0002` | no |
# | `weight_decay` | `float` | `0.0001` | no |
# | `gradient_clip_norm` | `float \| None` | `5.0` | no |
# | `physics_loss_weight` | `float` | `0.08` | no |
# | `entropy_consistency_weight` | `float` | `0.2` | no |
# | `patience` | `int` | `35` | no |
# | `min_delta` | `float` | `1e-05` | no |
# | `device` | `str` | `'auto'` | no |
# | `dtype` | `str` | `'float32'` | no |
# | `seed` | `int` | `42` | no |
# | `deterministic` | `bool` | `False` | no |
# | `workspace_root` | `str \| Path \| None` | `None` | no |
# | `run_name` | `str \| None` | `None` | no |

# %%
import inspect

if API is not None:
    try:
        print(inspect.signature(API))
    except (TypeError, ValueError):
        print('This public object has no callable signature.')
    summary = (getattr(API, '__doc__', None) or '').strip()
    print(summary.split('\n\n', 1)[0] if summary else 'No public docstring.')

# %% [markdown]
# ## Minimal public usage
#
# The example below stays on the public API surface.

# %%
if API is not None:
    value = API()
    print(value)

# %% [markdown]
# ## Expected behavior and common failures
#
# - Validate shapes, units, optional dependencies, and output paths before production use.
#
# For dataset downloads, model training, molecular dynamics, and external engines, first test with a small input and an explicit output directory.
