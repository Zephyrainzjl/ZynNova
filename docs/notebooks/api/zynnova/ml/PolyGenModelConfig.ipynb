# %% [markdown]
# # `zynnova.ml.PolyGenModelConfig`
#
# Public API notebook for **PolyGenModelConfig**. This page only uses the supported public import path and intentionally omits internal implementation details.
#
# **Purpose:** Public dataclass `PolyGenModelConfig`.

# %% [markdown]
# ## Installation
#
# Recommended installation for this API: `pip install 'zynnova[ml-generation]'`.
#
# Run this notebook from an environment where ZynNova is installed. Expensive downloads, training, visualization, and simulations are disabled by default.

# %%
try:
    from zynnova.ml import PolyGenModelConfig as API
except ImportError as exc:
    API = None
    print('Optional dependency or installation is missing:', exc)
else:
    print('Imported: zynnova.ml.PolyGenModelConfig')

# %% [markdown]
# ## Signature
#
# ```python
# PolyGenModelConfig(property_specs: tuple[PropertySpec, ...] = ENERGY_STORAGE_PROPERTIES, process_condition_names: tuple[str, ...] = ENERGY_STORAGE_CONDITIONS, representation: GenerationRepresentation = 'polymer_selfies', repair_missing_ports: bool = True, vocab_size: int = 0, max_length: int = 192, hidden_dim: int = 384, num_layers: int = 10, attention_heads: int = 12, feedforward_multiplier: int = 4, dropout: float = 0.1)
# ```
#
# | Parameter | Type | Default | Required |
# |---|---|---|---|
# | `property_specs` | `tuple[PropertySpec, ...]` | `ENERGY_STORAGE_PROPERTIES` | no |
# | `process_condition_names` | `tuple[str, ...]` | `ENERGY_STORAGE_CONDITIONS` | no |
# | `representation` | `GenerationRepresentation` | `'polymer_selfies'` | no |
# | `repair_missing_ports` | `bool` | `True` | no |
# | `vocab_size` | `int` | `0` | no |
# | `max_length` | `int` | `192` | no |
# | `hidden_dim` | `int` | `384` | no |
# | `num_layers` | `int` | `10` | no |
# | `attention_heads` | `int` | `12` | no |
# | `feedforward_multiplier` | `int` | `4` | no |
# | `dropout` | `float` | `0.1` | no |

# %%
import inspect

if API is not None:
    try:
        print(inspect.signature(API))
    except (TypeError, ValueError):
        print('This public object has no callable signature.')
    summary = (getattr(API, '__doc__', None) or '').strip()
    print(summary.split('\n\n', 1)[0] if summary else 'No public docstring.')

# %% [markdown]
# ## Minimal public usage
#
# The example below stays on the public API surface.

# %%
if API is not None:
    value = API()
    print(value)

# %% [markdown]
# ## Expected behavior and common failures
#
# - `ValueError("representation must be either 'psmiles' or 'polymer_selfies'")`
# - `ValueError('hidden_dim must be divisible by attention_heads')`
# - `ValueError('vocab_size must contain the five special tokens')`
# - `ValueError('property names must be unique')`
#
# For dataset downloads, model training, molecular dynamics, and external engines, first test with a small input and an explicit output directory.
