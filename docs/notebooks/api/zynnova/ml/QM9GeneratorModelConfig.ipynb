# %% [markdown]
# # `zynnova.ml.QM9GeneratorModelConfig`
#
# Public API notebook for **QM9GeneratorModelConfig**. This page only uses the supported public import path and intentionally omits internal implementation details.
#
# **Purpose:** Neural architecture for property-conditioned QM9 coordinate generation.

# %% [markdown]
# ## Installation
#
# Recommended installation for this API: `pip install 'zynnova[ml-generation]'`.
#
# Run this notebook from an environment where ZynNova is installed. Expensive downloads, training, visualization, and simulations are disabled by default.

# %%
try:
    from zynnova.ml import QM9GeneratorModelConfig as API
except ImportError as exc:
    API = None
    print('Optional dependency or installation is missing:', exc)
else:
    print('Imported: zynnova.ml.QM9GeneratorModelConfig')

# %% [markdown]
# ## Signature
#
# ```python
# QM9GeneratorModelConfig(property_names: tuple[str, ...] = ('gap', 'mu', 'alpha'), max_atomic_number: int = 20, max_atoms: int = 29, hidden_dim: int = 128, num_flow_layers: int = 5, num_property_layers: int = 4, num_rbf: int = 32, cutoff_A: float = 8.0, time_embedding_dim: int = 64, condition_hidden_dim: int = 128, property_head_hidden_dim: int = 128)
# ```
#
# | Parameter | Type | Default | Required |
# |---|---|---|---|
# | `property_names` | `tuple[str, ...]` | `('gap', 'mu', 'alpha')` | no |
# | `max_atomic_number` | `int` | `20` | no |
# | `max_atoms` | `int` | `29` | no |
# | `hidden_dim` | `int` | `128` | no |
# | `num_flow_layers` | `int` | `5` | no |
# | `num_property_layers` | `int` | `4` | no |
# | `num_rbf` | `int` | `32` | no |
# | `cutoff_A` | `float` | `8.0` | no |
# | `time_embedding_dim` | `int` | `64` | no |
# | `condition_hidden_dim` | `int` | `128` | no |
# | `property_head_hidden_dim` | `int` | `128` | no |

# %%
import inspect

if API is not None:
    try:
        print(inspect.signature(API))
    except (TypeError, ValueError):
        print('This public object has no callable signature.')
    summary = (getattr(API, '__doc__', None) or '').strip()
    print(summary.split('\n\n', 1)[0] if summary else 'No public docstring.')

# %% [markdown]
# ## Minimal public usage
#
# The example below stays on the public API surface.

# %%
if API is not None:
    value = API()
    print(value)

# %% [markdown]
# ## Expected behavior and common failures
#
# - `ValueError('property_names cannot be empty')`
# - `ValueError(f'unknown QM9 properties: {unknown}')`
# - `ValueError('property_names must be unique')`
# - `ValueError('cutoff_A must be positive')`
# - `ValueError(f'{name} must be positive')`
#
# For dataset downloads, model training, molecular dynamics, and external engines, first test with a small input and an explicit output directory.
