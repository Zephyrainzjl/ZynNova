# %% [markdown]
# # `zynnova.ml.polymer_selfies_to_psmiles`
#
# Public API notebook for **polymer_selfies_to_psmiles**. This page only uses the supported public import path and intentionally omits internal implementation details.
#
# **Purpose:** Decode Polymer-SELFIES to a valid, exactly two-port PSMILES string.

# %% [markdown]
# ## Installation
#
# Recommended installation for this API: `pip install 'zynnova[ml-generation]'`.
#
# Run this notebook from an environment where ZynNova is installed. Expensive downloads, training, visualization, and simulations are disabled by default.

# %%
try:
    from zynnova.ml import polymer_selfies_to_psmiles as API
except ImportError as exc:
    API = None
    print('Optional dependency or installation is missing:', exc)
else:
    print('Imported: zynnova.ml.polymer_selfies_to_psmiles')

# %% [markdown]
# ## Signature
#
# ```python
# polymer_selfies_to_psmiles(polymer_selfies: str, *, repair_missing_ports: bool = True) -> str
# ```
#
# | Parameter | Type | Default | Required |
# |---|---|---|---|
# | `polymer_selfies` | `str` | `-` | yes |
# | `repair_missing_ports` | `bool` | `True` | no |

# %%
import inspect

if API is not None:
    try:
        print(inspect.signature(API))
    except (TypeError, ValueError):
        print('This public object has no callable signature.')
    summary = (getattr(API, '__doc__', None) or '').strip()
    print(summary.split('\n\n', 1)[0] if summary else 'No public docstring.')

# %% [markdown]
# ## Minimal public usage
#
# The example below stays on the public API surface.

# %%
RUN_EXAMPLE = False  # Set True after replacing placeholders with your data.

if API is not None and RUN_EXAMPLE:
    result = API(...)  # Signature: polymer_selfies_to_psmiles(polymer_selfies: str, *, repair_missing_ports: bool = True) -> str
    print(result)

# %% [markdown]
# ## Expected behavior and common failures
#
# - `ValueError(f'RDKit rejected SELFIES-decoded SMILES: {surrogate_smiles!r}')`
# - `ValueError(f'decoded Polymer-SELFIES must retain exactly two port surrogates; found {xenon_count}')`
# - `ValueError('RDKit could not reparse restored PSMILES')`
# - `ValueError('SELFIES decoder rejected the generated token sequence')`
# - `ValueError('generated Polymer-SELFIES contains no molecular core')`
# - `ValueError('RDKit rejected the port-free SELFIES molecular core')`
# - `ValueError('SELFIES decoder rejected the port-free molecular core')`
#
# For dataset downloads, model training, molecular dynamics, and external engines, first test with a small input and an explicit output directory.
