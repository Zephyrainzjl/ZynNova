# %% [markdown]
# # `zynnova.ml.prepare_qm9_generator_data`
#
# Public API notebook for **prepare_qm9_generator_data**. This page only uses the supported public import path and intentionally omits internal implementation details.
#
# **Purpose:** Public function `prepare_qm9_generator_data`.

# %% [markdown]
# ## Installation
#
# Recommended installation for this API: `pip install 'zynnova[ml-generation]'`.
#
# Run this notebook from an environment where ZynNova is installed. Expensive downloads, training, visualization, and simulations are disabled by default.

# %%
try:
    from zynnova.ml import prepare_qm9_generator_data as API
except ImportError as exc:
    API = None
    print('Optional dependency or installation is missing:', exc)
else:
    print('Imported: zynnova.ml.prepare_qm9_generator_data')

# %% [markdown]
# ## Signature
#
# ```python
# prepare_qm9_generator_data(data_config: QM9GeneratorDataConfig, model_config: QM9GeneratorModelConfig, *, workspace: MLWorkspace) -> QM9GeneratorDataModule
# ```
#
# | Parameter | Type | Default | Required |
# |---|---|---|---|
# | `data_config` | `QM9GeneratorDataConfig` | `-` | yes |
# | `model_config` | `QM9GeneratorModelConfig` | `-` | yes |
# | `workspace` | `MLWorkspace` | `-` | yes |

# %%
import inspect

if API is not None:
    try:
        print(inspect.signature(API))
    except (TypeError, ValueError):
        print('This public object has no callable signature.')
    summary = (getattr(API, '__doc__', None) or '').strip()
    print(summary.split('\n\n', 1)[0] if summary else 'No public docstring.')

# %% [markdown]
# ## Minimal public usage
#
# The example below stays on the public API surface.

# %%
RUN_EXAMPLE = False  # Set True after replacing placeholders with your data.

if API is not None and RUN_EXAMPLE:
    result = API(...)  # Signature: prepare_qm9_generator_data(data_config: QM9GeneratorDataConfig, model_config: QM9GeneratorModelConfig, *, workspace: MLWorkspace) -> QM9GeneratorDataModule
    print(result)

# %% [markdown]
# ## Expected behavior and common failures
#
# - `ValueError('qm9_generator currently targets the QM9 dataset')`
# - `ValueError('qm9_generator needs at least three usable samples after filtering')`
#
# For dataset downloads, model training, molecular dynamics, and external engines, first test with a small input and an explicit output directory.
