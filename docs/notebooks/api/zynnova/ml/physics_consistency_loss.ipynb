# %% [markdown]
# # `zynnova.ml.physics_consistency_loss`
#
# Public API notebook for **physics_consistency_loss**. This page only uses the supported public import path and intentionally omits internal implementation details.
#
# **Purpose:** Differentiable constraints derived from the paper's energy-storage physics.

# %% [markdown]
# ## Installation
#
# Recommended installation for this API: `pip install 'zynnova[ml-all]'`.
#
# Run this notebook from an environment where ZynNova is installed. Expensive downloads, training, visualization, and simulations are disabled by default.

# %%
try:
    from zynnova.ml import physics_consistency_loss as API
except ImportError as exc:
    API = None
    print('Optional dependency or installation is missing:', exc)
else:
    print('Imported: zynnova.ml.physics_consistency_loss')

# %% [markdown]
# ## Signature
#
# ```python
# physics_consistency_loss(normalized_mean: Any, batch: Any, *, normalizer: Any, property_names: tuple[str, ...], condition_names: tuple[str, ...], entropy_weight: float = 0.2) -> Any
# ```
#
# | Parameter | Type | Default | Required |
# |---|---|---|---|
# | `normalized_mean` | `Any` | `-` | yes |
# | `batch` | `Any` | `-` | yes |
# | `normalizer` | `Any` | `-` | yes |
# | `property_names` | `tuple[str, ...]` | `-` | yes |
# | `condition_names` | `tuple[str, ...]` | `-` | yes |
# | `entropy_weight` | `float` | `0.2` | no |

# %%
import inspect

if API is not None:
    try:
        print(inspect.signature(API))
    except (TypeError, ValueError):
        print('This public object has no callable signature.')
    summary = (getattr(API, '__doc__', None) or '').strip()
    print(summary.split('\n\n', 1)[0] if summary else 'No public docstring.')

# %% [markdown]
# ## Minimal public usage
#
# The example below stays on the public API surface.

# %%
RUN_EXAMPLE = False  # Set True after replacing placeholders with your data.

if API is not None and RUN_EXAMPLE:
    result = API(...)  # Signature: physics_consistency_loss(normalized_mean: Any, batch: Any, *, normalizer: Any, property_names: tuple[str, ...], condition_names: tuple[str, ...], entropy_weight: float = 0.2) -> Any
    print(result)

# %% [markdown]
# ## Expected behavior and common failures
#
# - Validate shapes, units, optional dependencies, and output paths before production use.
#
# For dataset downloads, model training, molecular dynamics, and external engines, first test with a small input and an explicit output directory.
