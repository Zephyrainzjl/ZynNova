# %% [markdown]
# # `zynnova.ml.prepare_matbench_data`
#
# Public API notebook for **prepare_matbench_data**. This page only uses the supported public import path and intentionally omits internal implementation details.
#
# **Purpose:** Public function `prepare_matbench_data`.

# %% [markdown]
# ## Installation
#
# Recommended installation for this API: `pip install 'zynnova[ml-all]'`.
#
# Run this notebook from an environment where ZynNova is installed. Expensive downloads, training, visualization, and simulations are disabled by default.

# %%
try:
    from zynnova.ml import prepare_matbench_data as API
except ImportError as exc:
    API = None
    print('Optional dependency or installation is missing:', exc)
else:
    print('Imported: zynnova.ml.prepare_matbench_data')

# %% [markdown]
# ## Signature
#
# ```python
# prepare_matbench_data(data_config: CrystalGNNDataConfig, model_config: CrystalGNNModelConfig, *, workspace: MLWorkspace) -> CrystalGNNDataModule
# ```
#
# | Parameter | Type | Default | Required |
# |---|---|---|---|
# | `data_config` | `CrystalGNNDataConfig` | `-` | yes |
# | `model_config` | `CrystalGNNModelConfig` | `-` | yes |
# | `workspace` | `MLWorkspace` | `-` | yes |

# %%
import inspect

if API is not None:
    try:
        print(inspect.signature(API))
    except (TypeError, ValueError):
        print('This public object has no callable signature.')
    summary = (getattr(API, '__doc__', None) or '').strip()
    print(summary.split('\n\n', 1)[0] if summary else 'No public docstring.')

# %% [markdown]
# ## Minimal public usage
#
# The example below stays on the public API surface.

# %%
RUN_EXAMPLE = False  # Set True after replacing placeholders with your data.

if API is not None and RUN_EXAMPLE:
    result = API(...)  # Signature: prepare_matbench_data(data_config: CrystalGNNDataConfig, model_config: CrystalGNNModelConfig, *, workspace: MLWorkspace) -> CrystalGNNDataModule
    print(result)

# %% [markdown]
# ## Expected behavior and common failures
#
# - `ValueError('the bundled crystal GNN currently targets Matbench')`
#
# For dataset downloads, model training, molecular dynamics, and external engines, first test with a small input and an explicit output directory.
