# %% [markdown]
# # `zynnova.ml.QM9GeneratorDataConfig`
#
# Public API notebook for **QM9GeneratorDataConfig**. This page only uses the supported public import path and intentionally omits internal implementation details.
#
# **Purpose:** Public dataclass `QM9GeneratorDataConfig`.

# %% [markdown]
# ## Installation
#
# Recommended installation for this API: `pip install 'zynnova[ml-generation]'`.
#
# Run this notebook from an environment where ZynNova is installed. Expensive downloads, training, visualization, and simulations are disabled by default.

# %%
try:
    from zynnova.ml import QM9GeneratorDataConfig as API
except ImportError as exc:
    API = None
    print('Optional dependency or installation is missing:', exc)
else:
    print('Imported: zynnova.ml.QM9GeneratorDataConfig')

# %% [markdown]
# ## Signature
#
# ```python
# QM9GeneratorDataConfig(dataset: str = 'qm9', limit: int | None = None, batch_size: int = 64, num_workers: int = 0, train_ratio: float = 0.8, valid_ratio: float = 0.1, test_ratio: float = 0.1, seed: int = 42, require_all_properties: bool = True, local_file: str | Path | None = None, local_dir: str | Path | None = None, pin_memory: bool = True)
# ```
#
# | Parameter | Type | Default | Required |
# |---|---|---|---|
# | `dataset` | `str` | `'qm9'` | no |
# | `limit` | `int \| None` | `None` | no |
# | `batch_size` | `int` | `64` | no |
# | `num_workers` | `int` | `0` | no |
# | `train_ratio` | `float` | `0.8` | no |
# | `valid_ratio` | `float` | `0.1` | no |
# | `test_ratio` | `float` | `0.1` | no |
# | `seed` | `int` | `42` | no |
# | `require_all_properties` | `bool` | `True` | no |
# | `local_file` | `str \| Path \| None` | `None` | no |
# | `local_dir` | `str \| Path \| None` | `None` | no |
# | `pin_memory` | `bool` | `True` | no |

# %%
import inspect

if API is not None:
    try:
        print(inspect.signature(API))
    except (TypeError, ValueError):
        print('This public object has no callable signature.')
    summary = (getattr(API, '__doc__', None) or '').strip()
    print(summary.split('\n\n', 1)[0] if summary else 'No public docstring.')

# %% [markdown]
# ## Minimal public usage
#
# The example below stays on the public API surface.

# %%
if API is not None:
    value = API()
    print(value)

# %% [markdown]
# ## Expected behavior and common failures
#
# - `ValueError('limit must be positive or None')`
# - `ValueError('batch_size must be positive')`
# - `ValueError('num_workers cannot be negative')`
# - `ValueError('split ratios cannot be negative')`
# - `ValueError('train/valid/test ratios must sum to one')`
# - `ValueError('local_file and local_dir are mutually exclusive')`
#
# For dataset downloads, model training, molecular dynamics, and external engines, first test with a small input and an explicit output directory.
