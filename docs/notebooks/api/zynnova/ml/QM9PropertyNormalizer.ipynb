# %% [markdown]
# # `zynnova.ml.QM9PropertyNormalizer`
#
# Public API notebook for **QM9PropertyNormalizer**. This page only uses the supported public import path and intentionally omits internal implementation details.
#
# **Purpose:** Per-property standardization fitted only on the training split.

# %% [markdown]
# ## Installation
#
# Recommended installation for this API: `pip install 'zynnova[ml-generation]'`.
#
# Run this notebook from an environment where ZynNova is installed. Expensive downloads, training, visualization, and simulations are disabled by default.

# %%
try:
    from zynnova.ml import QM9PropertyNormalizer as API
except ImportError as exc:
    API = None
    print('Optional dependency or installation is missing:', exc)
else:
    print('Imported: zynnova.ml.QM9PropertyNormalizer')

# %% [markdown]
# ## Signature
#
# ```python
# QM9PropertyNormalizer(names: tuple[str, ...], mean: np.ndarray, std: np.ndarray, count: np.ndarray)
# ```
#
# | Parameter | Type | Default | Required |
# |---|---|---|---|
# | `names` | `tuple[str, ...]` | `-` | yes |
# | `mean` | `np.ndarray` | `-` | yes |
# | `std` | `np.ndarray` | `-` | yes |
# | `count` | `np.ndarray` | `-` | yes |

# %%
import inspect

if API is not None:
    try:
        print(inspect.signature(API))
    except (TypeError, ValueError):
        print('This public object has no callable signature.')
    summary = (getattr(API, '__doc__', None) or '').strip()
    print(summary.split('\n\n', 1)[0] if summary else 'No public docstring.')

# %% [markdown]
# ## Minimal public usage
#
# The example below stays on the public API surface.

# %%
RUN_EXAMPLE = False  # Set True after supplying the required constructor values.

if API is not None and RUN_EXAMPLE:
    value = API(...)  # Signature: QM9PropertyNormalizer(names: tuple[str, ...], mean: np.ndarray, std: np.ndarray, count: np.ndarray)
    print(value)

# %% [markdown]
# ## Expected behavior and common failures
#
# - `ValueError('mean/std must match property names')`
# - `ValueError('count must match property names')`
# - `ValueError('normalizer statistics must be finite')`
# - `ValueError('normalizer std must be positive')`
# - `ValueError(f'cannot fit normalizer; no finite values for {missing}')`
# - `ValueError(f'properties {unknown} were not used to train this model; available={self.names}')`
# - `ValueError('property vector has the wrong size')`
# - `ValueError(f'property {name!r} must be finite')`
#
# For dataset downloads, model training, molecular dynamics, and external engines, first test with a small input and an explicit output directory.
