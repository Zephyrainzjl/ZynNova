# %% [markdown]
# # `zynnova.ml.sample_qm9_coordinates`
#
# Public API notebook for **sample_qm9_coordinates**. This page only uses the supported public import path and intentionally omits internal implementation details.
#
# **Purpose:** Public function `sample_qm9_coordinates`.

# %% [markdown]
# ## Installation
#
# Recommended installation for this API: `pip install 'zynnova[ml-generation]'`.
#
# Run this notebook from an environment where ZynNova is installed. Expensive downloads, training, visualization, and simulations are disabled by default.

# %%
try:
    from zynnova.ml import sample_qm9_coordinates as API
except ImportError as exc:
    API = None
    print('Optional dependency or installation is missing:', exc)
else:
    print('Imported: zynnova.ml.sample_qm9_coordinates')

# %% [markdown]
# ## Signature
#
# ```python
# sample_qm9_coordinates(model: QM9EquivariantFlow, atomic_numbers: Iterable[int] | list[list[int]], *, steps: int = 100, noise_scale_A: float = 1.0, device: str = 'auto', seed: int | None = None) -> Any
# ```
#
# | Parameter | Type | Default | Required |
# |---|---|---|---|
# | `model` | `QM9EquivariantFlow` | `-` | yes |
# | `atomic_numbers` | `Iterable[int] \| list[list[int]]` | `-` | yes |
# | `steps` | `int` | `100` | no |
# | `noise_scale_A` | `float` | `1.0` | no |
# | `device` | `str` | `'auto'` | no |
# | `seed` | `int \| None` | `None` | no |

# %%
import inspect

if API is not None:
    try:
        print(inspect.signature(API))
    except (TypeError, ValueError):
        print('This public object has no callable signature.')
    summary = (getattr(API, '__doc__', None) or '').strip()
    print(summary.split('\n\n', 1)[0] if summary else 'No public docstring.')

# %% [markdown]
# ## Minimal public usage
#
# The example below stays on the public API surface.

# %%
RUN_EXAMPLE = False  # Set True after replacing placeholders with your data.

if API is not None and RUN_EXAMPLE:
    result = API(...)  # Signature: sample_qm9_coordinates(model: QM9EquivariantFlow, atomic_numbers: Iterable[int] | list[list[int]], *, steps: int = 100, noise_scale_A: float = 1.0, device: str = 'auto', seed: int | None = None) -> Any
    print(result)

# %% [markdown]
# ## Expected behavior and common failures
#
# - `ValueError('atomic_numbers cannot be empty')`
# - `ValueError(f'composition has {len(composition)} atoms, max_atoms={max_atoms}')`
#
# For dataset downloads, model training, molecular dynamics, and external engines, first test with a small input and an explicit output directory.
