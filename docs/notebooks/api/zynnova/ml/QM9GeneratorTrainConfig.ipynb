# %% [markdown]
# # `zynnova.ml.QM9GeneratorTrainConfig`
#
# Public API notebook for **QM9GeneratorTrainConfig**. This page only uses the supported public import path and intentionally omits internal implementation details.
#
# **Purpose:** Public dataclass `QM9GeneratorTrainConfig`.

# %% [markdown]
# ## Installation
#
# Recommended installation for this API: `pip install 'zynnova[ml-generation]'`.
#
# Run this notebook from an environment where ZynNova is installed. Expensive downloads, training, visualization, and simulations are disabled by default.

# %%
try:
    from zynnova.ml import QM9GeneratorTrainConfig as API
except ImportError as exc:
    API = None
    print('Optional dependency or installation is missing:', exc)
else:
    print('Imported: zynnova.ml.QM9GeneratorTrainConfig')

# %% [markdown]
# ## Signature
#
# ```python
# QM9GeneratorTrainConfig(epochs: int = 300, learning_rate: float = 0.0002, weight_decay: float = 1e-06, flow_loss_weight: float = 1.0, property_loss_weight: float = 0.25, condition_dropout: float = 0.1, gradient_clip_norm: float | None = 10.0, patience: int = 40, min_delta: float = 1e-06, device: str = 'auto', dtype: str = 'float32', seed: int = 42, deterministic: bool = False, workspace_root: str | Path | None = None, run_name: str | None = None)
# ```
#
# | Parameter | Type | Default | Required |
# |---|---|---|---|
# | `epochs` | `int` | `300` | no |
# | `learning_rate` | `float` | `0.0002` | no |
# | `weight_decay` | `float` | `1e-06` | no |
# | `flow_loss_weight` | `float` | `1.0` | no |
# | `property_loss_weight` | `float` | `0.25` | no |
# | `condition_dropout` | `float` | `0.1` | no |
# | `gradient_clip_norm` | `float \| None` | `10.0` | no |
# | `patience` | `int` | `40` | no |
# | `min_delta` | `float` | `1e-06` | no |
# | `device` | `str` | `'auto'` | no |
# | `dtype` | `str` | `'float32'` | no |
# | `seed` | `int` | `42` | no |
# | `deterministic` | `bool` | `False` | no |
# | `workspace_root` | `str \| Path \| None` | `None` | no |
# | `run_name` | `str \| None` | `None` | no |

# %%
import inspect

if API is not None:
    try:
        print(inspect.signature(API))
    except (TypeError, ValueError):
        print('This public object has no callable signature.')
    summary = (getattr(API, '__doc__', None) or '').strip()
    print(summary.split('\n\n', 1)[0] if summary else 'No public docstring.')

# %% [markdown]
# ## Minimal public usage
#
# The example below stays on the public API surface.

# %%
if API is not None:
    value = API()
    print(value)

# %% [markdown]
# ## Expected behavior and common failures
#
# - `ValueError('epochs must be positive')`
# - `ValueError('learning_rate must be positive')`
# - `ValueError('weight_decay cannot be negative')`
# - `ValueError('flow_loss_weight must be positive')`
# - `ValueError('property_loss_weight cannot be negative')`
# - `ValueError('condition_dropout must be in [0, 1)')`
# - `ValueError('gradient_clip_norm must be positive or None')`
# - `ValueError('patience must be positive')`
#
# For dataset downloads, model training, molecular dynamics, and external engines, first test with a small input and an explicit output directory.
