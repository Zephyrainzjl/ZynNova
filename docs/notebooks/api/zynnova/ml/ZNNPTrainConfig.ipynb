# %% [markdown]
# # `zynnova.ml.ZNNPTrainConfig`
#
# Public API notebook for **ZNNPTrainConfig**. This page only uses the supported public import path and intentionally omits internal implementation details.
#
# **Purpose:** Public dataclass `ZNNPTrainConfig`.

# %% [markdown]
# ## Installation
#
# Recommended installation for this API: `pip install 'zynnova[mlff]'`.
#
# Run this notebook from an environment where ZynNova is installed. Expensive downloads, training, visualization, and simulations are disabled by default.

# %%
try:
    from zynnova.ml import ZNNPTrainConfig as API
except ImportError as exc:
    API = None
    print('Optional dependency or installation is missing:', exc)
else:
    print('Imported: zynnova.ml.ZNNPTrainConfig')

# %% [markdown]
# ## Signature
#
# ```python
# ZNNPTrainConfig(epochs: int = 300, learning_rate: float = 0.001, weight_decay: float = 1e-06, energy_weight: float = 1.0, force_weight: float = 100.0, gradient_clip_norm: float | None = 10.0, patience: int = 50, min_delta: float = 1e-06, device: str = 'auto', dtype: str = 'float32', seed: int = 42, deterministic: bool = False, workspace_root: str | Path | None = None, run_name: str | None = None)
# ```
#
# | Parameter | Type | Default | Required |
# |---|---|---|---|
# | `epochs` | `int` | `300` | no |
# | `learning_rate` | `float` | `0.001` | no |
# | `weight_decay` | `float` | `1e-06` | no |
# | `energy_weight` | `float` | `1.0` | no |
# | `force_weight` | `float` | `100.0` | no |
# | `gradient_clip_norm` | `float \| None` | `10.0` | no |
# | `patience` | `int` | `50` | no |
# | `min_delta` | `float` | `1e-06` | no |
# | `device` | `str` | `'auto'` | no |
# | `dtype` | `str` | `'float32'` | no |
# | `seed` | `int` | `42` | no |
# | `deterministic` | `bool` | `False` | no |
# | `workspace_root` | `str \| Path \| None` | `None` | no |
# | `run_name` | `str \| None` | `None` | no |

# %%
import inspect

if API is not None:
    try:
        print(inspect.signature(API))
    except (TypeError, ValueError):
        print('This public object has no callable signature.')
    summary = (getattr(API, '__doc__', None) or '').strip()
    print(summary.split('\n\n', 1)[0] if summary else 'No public docstring.')

# %% [markdown]
# ## Minimal public usage
#
# The example below stays on the public API surface.

# %%
if API is not None:
    value = API()
    print(value)

# %% [markdown]
# ## Expected behavior and common failures
#
# - Validate shapes, units, optional dependencies, and output paths before production use.
#
# For dataset downloads, model training, molecular dynamics, and external engines, first test with a small input and an explicit output directory.
