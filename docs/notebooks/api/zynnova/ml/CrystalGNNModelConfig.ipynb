# %% [markdown]
# # `zynnova.ml.CrystalGNNModelConfig`
#
# Public API notebook for **CrystalGNNModelConfig**. This page only uses the supported public import path and intentionally omits internal implementation details.
#
# **Purpose:** Public dataclass `CrystalGNNModelConfig`.

# %% [markdown]
# ## Installation
#
# Recommended installation for this API: `pip install 'zynnova[ml-all]'`.
#
# Run this notebook from an environment where ZynNova is installed. Expensive downloads, training, visualization, and simulations are disabled by default.

# %%
try:
    from zynnova.ml import CrystalGNNModelConfig as API
except ImportError as exc:
    API = None
    print('Optional dependency or installation is missing:', exc)
else:
    print('Imported: zynnova.ml.CrystalGNNModelConfig')

# %% [markdown]
# ## Signature
#
# ```python
# CrystalGNNModelConfig(max_atomic_number: int = 100, hidden_dim: int = 128, num_layers: int = 4, num_rbf: int = 48, cutoff_A: float = 5.0, max_neighbors: int | None = 64, target_mean: float = 0.0, target_std: float = 1.0)
# ```
#
# | Parameter | Type | Default | Required |
# |---|---|---|---|
# | `max_atomic_number` | `int` | `100` | no |
# | `hidden_dim` | `int` | `128` | no |
# | `num_layers` | `int` | `4` | no |
# | `num_rbf` | `int` | `48` | no |
# | `cutoff_A` | `float` | `5.0` | no |
# | `max_neighbors` | `int \| None` | `64` | no |
# | `target_mean` | `float` | `0.0` | no |
# | `target_std` | `float` | `1.0` | no |

# %%
import inspect

if API is not None:
    try:
        print(inspect.signature(API))
    except (TypeError, ValueError):
        print('This public object has no callable signature.')
    summary = (getattr(API, '__doc__', None) or '').strip()
    print(summary.split('\n\n', 1)[0] if summary else 'No public docstring.')

# %% [markdown]
# ## Minimal public usage
#
# The example below stays on the public API surface.

# %%
if API is not None:
    value = API()
    print(value)

# %% [markdown]
# ## Expected behavior and common failures
#
# - Validate shapes, units, optional dependencies, and output paths before production use.
#
# For dataset downloads, model training, molecular dynamics, and external engines, first test with a small input and an explicit output directory.
