# %% [markdown]
# # `zynnova.ml.QM9GeneratorSamplingConfig`
#
# Public API notebook for **QM9GeneratorSamplingConfig**. This page only uses the supported public import path and intentionally omits internal implementation details.
#
# **Purpose:** Public dataclass `QM9GeneratorSamplingConfig`.

# %% [markdown]
# ## Installation
#
# Recommended installation for this API: `pip install 'zynnova[ml-generation]'`.
#
# Run this notebook from an environment where ZynNova is installed. Expensive downloads, training, visualization, and simulations are disabled by default.

# %%
try:
    from zynnova.ml import QM9GeneratorSamplingConfig as API
except ImportError as exc:
    API = None
    print('Optional dependency or installation is missing:', exc)
else:
    print('Imported: zynnova.ml.QM9GeneratorSamplingConfig')

# %% [markdown]
# ## Signature
#
# ```python
# QM9GeneratorSamplingConfig(num_candidates: int = 32, steps: int = 200, solver: str = 'heun', noise_scale_A: float = 1.0, guidance_scale: float = 2.0, property_guidance_scale: float = 0.25, property_gradient_clip: float | None = 5.0, minimum_distance_A: float = 0.55, collision_guidance_scale: float = 0.2, bond_scale: float = 1.25, device: str = 'auto', seed: int | None = None)
# ```
#
# | Parameter | Type | Default | Required |
# |---|---|---|---|
# | `num_candidates` | `int` | `32` | no |
# | `steps` | `int` | `200` | no |
# | `solver` | `str` | `'heun'` | no |
# | `noise_scale_A` | `float` | `1.0` | no |
# | `guidance_scale` | `float` | `2.0` | no |
# | `property_guidance_scale` | `float` | `0.25` | no |
# | `property_gradient_clip` | `float \| None` | `5.0` | no |
# | `minimum_distance_A` | `float` | `0.55` | no |
# | `collision_guidance_scale` | `float` | `0.2` | no |
# | `bond_scale` | `float` | `1.25` | no |
# | `device` | `str` | `'auto'` | no |
# | `seed` | `int \| None` | `None` | no |

# %%
import inspect

if API is not None:
    try:
        print(inspect.signature(API))
    except (TypeError, ValueError):
        print('This public object has no callable signature.')
    summary = (getattr(API, '__doc__', None) or '').strip()
    print(summary.split('\n\n', 1)[0] if summary else 'No public docstring.')

# %% [markdown]
# ## Minimal public usage
#
# The example below stays on the public API surface.

# %%
if API is not None:
    value = API()
    print(value)

# %% [markdown]
# ## Expected behavior and common failures
#
# - `ValueError('num_candidates must be positive')`
# - `ValueError('steps must be positive')`
# - `ValueError("solver must be 'euler' or 'heun'")`
# - `ValueError('noise_scale_A must be positive')`
# - `ValueError('guidance_scale cannot be negative')`
# - `ValueError('property_guidance_scale cannot be negative')`
# - `ValueError('property_gradient_clip must be positive or None')`
# - `ValueError('minimum_distance_A must be positive')`
# - `ValueError('collision_guidance_scale cannot be negative')`
# - `ValueError('bond_scale must be positive')`
#
# For dataset downloads, model training, molecular dynamics, and external engines, first test with a small input and an explicit output directory.
