# %% [markdown]
# # `zynnova.ml.psmiles_to_polymer_selfies`
#
# Public API notebook for **psmiles_to_polymer_selfies**. This page only uses the supported public import path and intentionally omits internal implementation details.
#
# **Purpose:** Encode a two-port PSMILES repeat unit as robust Polymer-SELFIES.

# %% [markdown]
# ## Installation
#
# Recommended installation for this API: `pip install 'zynnova[ml-generation]'`.
#
# Run this notebook from an environment where ZynNova is installed. Expensive downloads, training, visualization, and simulations are disabled by default.

# %%
try:
    from zynnova.ml import psmiles_to_polymer_selfies as API
except ImportError as exc:
    API = None
    print('Optional dependency or installation is missing:', exc)
else:
    print('Imported: zynnova.ml.psmiles_to_polymer_selfies')

# %% [markdown]
# ## Signature
#
# ```python
# psmiles_to_polymer_selfies(psmiles: str) -> str
# ```
#
# | Parameter | Type | Default | Required |
# |---|---|---|---|
# | `psmiles` | `str` | `-` | yes |

# %%
import inspect

if API is not None:
    try:
        print(inspect.signature(API))
    except (TypeError, ValueError):
        print('This public object has no callable signature.')
    summary = (getattr(API, '__doc__', None) or '').strip()
    print(summary.split('\n\n', 1)[0] if summary else 'No public docstring.')

# %% [markdown]
# ## Minimal public usage
#
# The example below stays on the public API surface.

# %%
RUN_EXAMPLE = False  # Set True after replacing placeholders with your data.

if API is not None and RUN_EXAMPLE:
    result = API(...)  # Signature: psmiles_to_polymer_selfies(psmiles: str) -> str
    print(result)

# %% [markdown]
# ## Expected behavior and common failures
#
# - `ValueError(f'RDKit could not parse PSMILES: {psmiles!r}')`
# - `ValueError('native xenon atoms are reserved for Polymer-SELFIES port encoding')`
# - `ValueError(f'Polymer-SELFIES requires exactly two polymerization ports; found {len(ports)}')`
# - `ValueError('each Polymer-SELFIES port must be bonded to exactly one atom')`
# - `ValueError(f'SELFIES could not encode the port-surrogate SMILES {surrogate_smiles!r}')`
#
# For dataset downloads, model training, molecular dynamics, and external engines, first test with a small input and an explicit output directory.
