# %% [markdown]
# # `zynnova.ml.LAMMPSRunConfig`
#
# Public API notebook for **LAMMPSRunConfig**. This page only uses the supported public import path and intentionally omits internal implementation details.
#
# **Purpose:** Public dataclass `LAMMPSRunConfig`.

# %% [markdown]
# ## Installation
#
# Recommended installation for this API: `pip install 'zynnova[lammps]'`.
#
# Run this notebook from an environment where ZynNova is installed. Expensive downloads, training, visualization, and simulations are disabled by default.

# %%
try:
    from zynnova.ml import LAMMPSRunConfig as API
except ImportError as exc:
    API = None
    print('Optional dependency or installation is missing:', exc)
else:
    print('Imported: zynnova.ml.LAMMPSRunConfig')

# %% [markdown]
# ## Signature
#
# ```python
# LAMMPSRunConfig(steps: int = 1000, timestep_ps: float = 0.001, ensemble: str = 'nve', boundary: str = 'f f f', temperature_K: float = 300.0, initialize_velocities: bool = True, velocity_seed: int = 42, damping_ps: float = 0.1, thermo_interval: int = 10, dump_interval: int = 10, neighbor_skin_A: float = 2.0, workspace_root: str | Path | None = None, run_name: str | None = None)
# ```
#
# | Parameter | Type | Default | Required |
# |---|---|---|---|
# | `steps` | `int` | `1000` | no |
# | `timestep_ps` | `float` | `0.001` | no |
# | `ensemble` | `str` | `'nve'` | no |
# | `boundary` | `str` | `'f f f'` | no |
# | `temperature_K` | `float` | `300.0` | no |
# | `initialize_velocities` | `bool` | `True` | no |
# | `velocity_seed` | `int` | `42` | no |
# | `damping_ps` | `float` | `0.1` | no |
# | `thermo_interval` | `int` | `10` | no |
# | `dump_interval` | `int` | `10` | no |
# | `neighbor_skin_A` | `float` | `2.0` | no |
# | `workspace_root` | `str \| Path \| None` | `None` | no |
# | `run_name` | `str \| None` | `None` | no |

# %%
import inspect

if API is not None:
    try:
        print(inspect.signature(API))
    except (TypeError, ValueError):
        print('This public object has no callable signature.')
    summary = (getattr(API, '__doc__', None) or '').strip()
    print(summary.split('\n\n', 1)[0] if summary else 'No public docstring.')

# %% [markdown]
# ## Minimal public usage
#
# The example below stays on the public API surface.

# %%
if API is not None:
    value = API()
    print(value)

# %% [markdown]
# ## Expected behavior and common failures
#
# - Validate shapes, units, optional dependencies, and output paths before production use.
#
# For dataset downloads, model training, molecular dynamics, and external engines, first test with a small input and an explicit output directory.
