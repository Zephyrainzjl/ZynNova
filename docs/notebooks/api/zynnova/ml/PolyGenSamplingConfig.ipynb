# %% [markdown]
# # `zynnova.ml.PolyGenSamplingConfig`
#
# Public API notebook for **PolyGenSamplingConfig**. This page only uses the supported public import path and intentionally omits internal implementation details.
#
# **Purpose:** Public dataclass `PolyGenSamplingConfig`.

# %% [markdown]
# ## Installation
#
# Recommended installation for this API: `pip install 'zynnova[ml-generation]'`.
#
# Run this notebook from an environment where ZynNova is installed. Expensive downloads, training, visualization, and simulations are disabled by default.

# %%
try:
    from zynnova.ml import PolyGenSamplingConfig as API
except ImportError as exc:
    API = None
    print('Optional dependency or installation is missing:', exc)
else:
    print('Imported: zynnova.ml.PolyGenSamplingConfig')

# %% [markdown]
# ## Signature
#
# ```python
# PolyGenSamplingConfig(num_candidates: int = 32, oversample_factor: int = 8, max_sampling_rounds: int = 4, refinement_steps: int = 48, guidance_scale: float = 1.8, condition_z_clip: float | None = 3.0, temperature: float = 0.85, top_p: float = 0.95, minimum_length: int = 8, maximum_length: int | None = None, require_two_ports: bool = True, minimum_configurational_entropy_R: float | None = None, diversity_weight: float = 0.18, seed: int = 42)
# ```
#
# | Parameter | Type | Default | Required |
# |---|---|---|---|
# | `num_candidates` | `int` | `32` | no |
# | `oversample_factor` | `int` | `8` | no |
# | `max_sampling_rounds` | `int` | `4` | no |
# | `refinement_steps` | `int` | `48` | no |
# | `guidance_scale` | `float` | `1.8` | no |
# | `condition_z_clip` | `float \| None` | `3.0` | no |
# | `temperature` | `float` | `0.85` | no |
# | `top_p` | `float` | `0.95` | no |
# | `minimum_length` | `int` | `8` | no |
# | `maximum_length` | `int \| None` | `None` | no |
# | `require_two_ports` | `bool` | `True` | no |
# | `minimum_configurational_entropy_R` | `float \| None` | `None` | no |
# | `diversity_weight` | `float` | `0.18` | no |
# | `seed` | `int` | `42` | no |

# %%
import inspect

if API is not None:
    try:
        print(inspect.signature(API))
    except (TypeError, ValueError):
        print('This public object has no callable signature.')
    summary = (getattr(API, '__doc__', None) or '').strip()
    print(summary.split('\n\n', 1)[0] if summary else 'No public docstring.')

# %% [markdown]
# ## Minimal public usage
#
# The example below stays on the public API surface.

# %%
if API is not None:
    value = API()
    print(value)

# %% [markdown]
# ## Expected behavior and common failures
#
# - `ValueError('candidate count and oversample factor must be positive')`
# - `ValueError('max_sampling_rounds must be positive')`
# - `ValueError('refinement_steps must be positive')`
# - `ValueError('guidance_scale cannot be negative')`
# - `ValueError('condition_z_clip must be positive when supplied')`
# - `ValueError('top_p must lie in (0, 1]')`
# - `ValueError('temperature must be positive')`
# - `ValueError('minimum_length must leave room for BOS, content and EOS')`
# - `ValueError('maximum_length cannot be smaller than minimum_length')`
#
# For dataset downloads, model training, molecular dynamics, and external engines, first test with a small input and an explicit output directory.
