# %% [markdown]
# # `zynnova.ml.PolyPredictionModelConfig`
#
# Public API notebook for **PolyPredictionModelConfig**. This page only uses the supported public import path and intentionally omits internal implementation details.
#
# **Purpose:** Public dataclass `PolyPredictionModelConfig`.

# %% [markdown]
# ## Installation
#
# Recommended installation for this API: `pip install 'zynnova[ml-generation]'`.
#
# Run this notebook from an environment where ZynNova is installed. Expensive downloads, training, visualization, and simulations are disabled by default.

# %%
try:
    from zynnova.ml import PolyPredictionModelConfig as API
except ImportError as exc:
    API = None
    print('Optional dependency or installation is missing:', exc)
else:
    print('Imported: zynnova.ml.PolyPredictionModelConfig')

# %% [markdown]
# ## Signature
#
# ```python
# PolyPredictionModelConfig(property_specs: tuple[PropertySpec, ...] = ENERGY_STORAGE_PROPERTIES, condition_names: tuple[str, ...] = ENERGY_STORAGE_CONDITIONS, vocab_size: int = 0, max_length: int = 256, node_feature_dim: int = 7, edge_feature_dim: int = 4, hidden_dim: int = 256, sequence_layers: int = 6, graph_layers: int = 5, attention_heads: int = 8, feedforward_multiplier: int = 4, dropout: float = 0.12, min_log_variance: float = -8.0, max_log_variance: float = 5.0)
# ```
#
# | Parameter | Type | Default | Required |
# |---|---|---|---|
# | `property_specs` | `tuple[PropertySpec, ...]` | `ENERGY_STORAGE_PROPERTIES` | no |
# | `condition_names` | `tuple[str, ...]` | `ENERGY_STORAGE_CONDITIONS` | no |
# | `vocab_size` | `int` | `0` | no |
# | `max_length` | `int` | `256` | no |
# | `node_feature_dim` | `int` | `7` | no |
# | `edge_feature_dim` | `int` | `4` | no |
# | `hidden_dim` | `int` | `256` | no |
# | `sequence_layers` | `int` | `6` | no |
# | `graph_layers` | `int` | `5` | no |
# | `attention_heads` | `int` | `8` | no |
# | `feedforward_multiplier` | `int` | `4` | no |
# | `dropout` | `float` | `0.12` | no |
# | `min_log_variance` | `float` | `-8.0` | no |
# | `max_log_variance` | `float` | `5.0` | no |

# %%
import inspect

if API is not None:
    try:
        print(inspect.signature(API))
    except (TypeError, ValueError):
        print('This public object has no callable signature.')
    summary = (getattr(API, '__doc__', None) or '').strip()
    print(summary.split('\n\n', 1)[0] if summary else 'No public docstring.')

# %% [markdown]
# ## Minimal public usage
#
# The example below stays on the public API surface.

# %%
if API is not None:
    value = API()
    print(value)

# %% [markdown]
# ## Expected behavior and common failures
#
# - `ValueError('hidden_dim must be divisible by attention_heads')`
# - `ValueError('vocab_size must contain the five special tokens')`
# - `ValueError('property names must be unique')`
# - `ValueError('condition names must be unique')`
#
# For dataset downloads, model training, molecular dynamics, and external engines, first test with a small input and an explicit output directory.
