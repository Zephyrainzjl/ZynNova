# %% [markdown]
# # `zynnova.ml.LoadedPolyPredictor`
#
# Public API notebook for **LoadedPolyPredictor**. This page only uses the supported public import path and intentionally omits internal implementation details.
#
# **Purpose:** Public dataclass `LoadedPolyPredictor`.

# %% [markdown]
# ## Installation
#
# Recommended installation for this API: `pip install 'zynnova[ml-generation]'`.
#
# Run this notebook from an environment where ZynNova is installed. Expensive downloads, training, visualization, and simulations are disabled by default.

# %%
try:
    from zynnova.ml import LoadedPolyPredictor as API
except ImportError as exc:
    API = None
    print('Optional dependency or installation is missing:', exc)
else:
    print('Imported: zynnova.ml.LoadedPolyPredictor')

# %% [markdown]
# ## Signature
#
# ```python
# LoadedPolyPredictor(model: PolyPredictionNetwork, tokenizer: PSMILESTokenizer, target_normalizer: MaskedTargetNormalizer, condition_normalizer: MaskedFeatureNormalizer, device: Any, calibrator: ConformalCalibrator | None = None)
# ```
#
# | Parameter | Type | Default | Required |
# |---|---|---|---|
# | `model` | `PolyPredictionNetwork` | `-` | yes |
# | `tokenizer` | `PSMILESTokenizer` | `-` | yes |
# | `target_normalizer` | `MaskedTargetNormalizer` | `-` | yes |
# | `condition_normalizer` | `MaskedFeatureNormalizer` | `-` | yes |
# | `device` | `Any` | `-` | yes |
# | `calibrator` | `ConformalCalibrator \| None` | `None` | no |

# %%
import inspect

if API is not None:
    try:
        print(inspect.signature(API))
    except (TypeError, ValueError):
        print('This public object has no callable signature.')
    summary = (getattr(API, '__doc__', None) or '').strip()
    print(summary.split('\n\n', 1)[0] if summary else 'No public docstring.')

# %% [markdown]
# ## Minimal public usage
#
# The example below stays on the public API surface.

# %%
RUN_EXAMPLE = False  # Set True after supplying the required constructor values.

if API is not None and RUN_EXAMPLE:
    value = API(...)  # Signature: LoadedPolyPredictor(model: PolyPredictionNetwork, tokenizer: PSMILESTokenizer, target_normalizer: MaskedTargetNormalizer, condition_normalizer: MaskedFeatureNormalizer, device: Any, calibrator: ConformalCalibrator | None = None)
    print(value)

# %% [markdown]
# ## Expected behavior and common failures
#
# - Validate shapes, units, optional dependencies, and output paths before production use.
#
# For dataset downloads, model training, molecular dynamics, and external engines, first test with a small input and an explicit output directory.
