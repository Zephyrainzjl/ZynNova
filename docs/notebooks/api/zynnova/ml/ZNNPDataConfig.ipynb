# %% [markdown]
# # `zynnova.ml.ZNNPDataConfig`
#
# Public API notebook for **ZNNPDataConfig**. This page only uses the supported public import path and intentionally omits internal implementation details.
#
# **Purpose:** Public dataclass `ZNNPDataConfig`.

# %% [markdown]
# ## Installation
#
# Recommended installation for this API: `pip install 'zynnova[mlff]'`.
#
# Run this notebook from an environment where ZynNova is installed. Expensive downloads, training, visualization, and simulations are disabled by default.

# %%
try:
    from zynnova.ml import ZNNPDataConfig as API
except ImportError as exc:
    API = None
    print('Optional dependency or installation is missing:', exc)
else:
    print('Imported: zynnova.ml.ZNNPDataConfig')

# %% [markdown]
# ## Signature
#
# ```python
# ZNNPDataConfig(dataset: str = 'rmd17', molecule: str = 'revised aspirin', limit: int = 1000, selection: str = 'random', local_file: str | Path | None = None, prefer_direct_download: bool = True, batch_size: int = 8, num_workers: int = 0, train_ratio: float = 0.8, valid_ratio: float = 0.1, test_ratio: float = 0.1, seed: int = 42)
# ```
#
# | Parameter | Type | Default | Required |
# |---|---|---|---|
# | `dataset` | `str` | `'rmd17'` | no |
# | `molecule` | `str` | `'revised aspirin'` | no |
# | `limit` | `int` | `1000` | no |
# | `selection` | `str` | `'random'` | no |
# | `local_file` | `str \| Path \| None` | `None` | no |
# | `prefer_direct_download` | `bool` | `True` | no |
# | `batch_size` | `int` | `8` | no |
# | `num_workers` | `int` | `0` | no |
# | `train_ratio` | `float` | `0.8` | no |
# | `valid_ratio` | `float` | `0.1` | no |
# | `test_ratio` | `float` | `0.1` | no |
# | `seed` | `int` | `42` | no |

# %%
import inspect

if API is not None:
    try:
        print(inspect.signature(API))
    except (TypeError, ValueError):
        print('This public object has no callable signature.')
    summary = (getattr(API, '__doc__', None) or '').strip()
    print(summary.split('\n\n', 1)[0] if summary else 'No public docstring.')

# %% [markdown]
# ## Minimal public usage
#
# The example below stays on the public API surface.

# %%
if API is not None:
    value = API()
    print(value)

# %% [markdown]
# ## Expected behavior and common failures
#
# - Validate shapes, units, optional dependencies, and output paths before production use.
#
# For dataset downloads, model training, molecular dynamics, and external engines, first test with a small input and an explicit output directory.
