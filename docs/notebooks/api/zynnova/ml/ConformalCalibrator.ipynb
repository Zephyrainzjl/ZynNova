# %% [markdown]
# # `zynnova.ml.ConformalCalibrator`
#
# Public API notebook for **ConformalCalibrator**. This page only uses the supported public import path and intentionally omits internal implementation details.
#
# **Purpose:** Per-property split-conformal residual calibration in physical units.

# %% [markdown]
# ## Installation
#
# Recommended installation for this API: `pip install 'zynnova[ml-all]'`.
#
# Run this notebook from an environment where ZynNova is installed. Expensive downloads, training, visualization, and simulations are disabled by default.

# %%
try:
    from zynnova.ml import ConformalCalibrator as API
except ImportError as exc:
    API = None
    print('Optional dependency or installation is missing:', exc)
else:
    print('Imported: zynnova.ml.ConformalCalibrator')

# %% [markdown]
# ## Signature
#
# ```python
# ConformalCalibrator(quantiles: dict[str, float], coverage: float = 0.9)
# ```
#
# | Parameter | Type | Default | Required |
# |---|---|---|---|
# | `quantiles` | `dict[str, float]` | `-` | yes |
# | `coverage` | `float` | `0.9` | no |

# %%
import inspect

if API is not None:
    try:
        print(inspect.signature(API))
    except (TypeError, ValueError):
        print('This public object has no callable signature.')
    summary = (getattr(API, '__doc__', None) or '').strip()
    print(summary.split('\n\n', 1)[0] if summary else 'No public docstring.')

# %% [markdown]
# ## Minimal public usage
#
# The example below stays on the public API surface.

# %%
RUN_EXAMPLE = False  # Set True after supplying the required constructor values.

if API is not None and RUN_EXAMPLE:
    value = API(...)  # Signature: ConformalCalibrator(quantiles: dict[str, float], coverage: float = 0.9)
    print(value)

# %% [markdown]
# ## Expected behavior and common failures
#
# - `ValueError('coverage must lie between zero and one')`
#
# For dataset downloads, model training, molecular dynamics, and external engines, first test with a small input and an explicit output directory.
