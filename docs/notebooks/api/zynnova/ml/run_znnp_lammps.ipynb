# %% [markdown]
# # `zynnova.ml.run_znnp_lammps`
#
# Public API notebook for **run_znnp_lammps**. This page only uses the supported public import path and intentionally omits internal implementation details.
#
# **Purpose:** Run an external ZNNP force field through the LAMMPS shared library.

# %% [markdown]
# ## Installation
#
# Recommended installation for this API: `pip install 'zynnova[lammps]'`.
#
# Run this notebook from an environment where ZynNova is installed. Expensive downloads, training, visualization, and simulations are disabled by default.

# %%
try:
    from zynnova.ml import run_znnp_lammps as API
except ImportError as exc:
    API = None
    print('Optional dependency or installation is missing:', exc)
else:
    print('Imported: zynnova.ml.run_znnp_lammps')

# %% [markdown]
# ## Signature
#
# ```python
# run_znnp_lammps(model: ZNNP, data_file: str | Path, *, atom_type_to_atomic_number: Mapping[int, int], config: LAMMPSRunConfig | None = None, device: str = 'auto') -> Any
# ```
#
# | Parameter | Type | Default | Required |
# |---|---|---|---|
# | `model` | `ZNNP` | `-` | yes |
# | `data_file` | `str \| Path` | `-` | yes |
# | `atom_type_to_atomic_number` | `Mapping[int, int]` | `-` | yes |
# | `config` | `LAMMPSRunConfig \| None` | `None` | no |
# | `device` | `str` | `'auto'` | no |

# %%
import inspect

if API is not None:
    try:
        print(inspect.signature(API))
    except (TypeError, ValueError):
        print('This public object has no callable signature.')
    summary = (getattr(API, '__doc__', None) or '').strip()
    print(summary.split('\n\n', 1)[0] if summary else 'No public docstring.')

# %% [markdown]
# ## Minimal public usage
#
# The example below stays on the public API surface.

# %%
RUN_EXAMPLE = False  # Set True after replacing placeholders with your data.

if API is not None and RUN_EXAMPLE:
    result = API(...)  # Signature: run_znnp_lammps(model: ZNNP, data_file: str | Path, *, atom_type_to_atomic_number: Mapping[int, int], config: LAMMPSRunConfig | None = None, device: str = 'auto') -> Any
    print(result)

# %% [markdown]
# ## Expected behavior and common failures
#
# - `ValueError('boundary must contain three LAMMPS boundary flags')`
# - `ImportError('LAMMPS Python bindings are required; install zynnova[lammps]')`
# - `ValueError("the reference LAMMPS bridge supports ensemble='nve' or 'nvt'")`
#
# For dataset downloads, model training, molecular dynamics, and external engines, first test with a small input and an explicit output directory.
