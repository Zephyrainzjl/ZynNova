# %% [markdown]
# # `zynnova.dynamics.staged_relax`
#
# Public API notebook for **staged_relax**. This page only uses the supported public import path and intentionally omits internal implementation details.
#
# **Purpose:** Public function `staged_relax`.

# %% [markdown]
# ## Installation
#
# Recommended installation for this API: `pip install 'zynnova[dynamics]'`.
#
# Run this notebook from an environment where ZynNova is installed. Expensive downloads, training, visualization, and simulations are disabled by default.

# %%
try:
    from zynnova.dynamics import staged_relax as API
except ImportError as exc:
    API = None
    print('Optional dependency or installation is missing:', exc)
else:
    print('Imported: zynnova.dynamics.staged_relax')

# %% [markdown]
# ## Signature
#
# ```python
# staged_relax(structure: Any, calculator: Any, stages: list[RelaxationConfig], *, output_directory: str | Path = 'zynnova-relax') -> list[RelaxationResult]
# ```
#
# | Parameter | Type | Default | Required |
# |---|---|---|---|
# | `structure` | `Any` | `-` | yes |
# | `calculator` | `Any` | `-` | yes |
# | `stages` | `list[RelaxationConfig]` | `-` | yes |
# | `output_directory` | `str \| Path` | `'zynnova-relax'` | no |

# %%
import inspect

if API is not None:
    try:
        print(inspect.signature(API))
    except (TypeError, ValueError):
        print('This public object has no callable signature.')
    summary = (getattr(API, '__doc__', None) or '').strip()
    print(summary.split('\n\n', 1)[0] if summary else 'No public docstring.')

# %% [markdown]
# ## Minimal public usage
#
# The example below stays on the public API surface.

# %%
RUN_EXAMPLE = False  # Set True after replacing placeholders with your data.

if API is not None and RUN_EXAMPLE:
    result = API(...)  # Signature: staged_relax(structure: Any, calculator: Any, stages: list[RelaxationConfig], *, output_directory: str | Path = 'zynnova-relax') -> list[RelaxationResult]
    print(result)

# %% [markdown]
# ## Expected behavior and common failures
#
# - `ValueError('stages cannot be empty')`
#
# For dataset downloads, model training, molecular dynamics, and external engines, first test with a small input and an explicit output directory.
