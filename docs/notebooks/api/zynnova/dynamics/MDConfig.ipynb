# %% [markdown]
# # `zynnova.dynamics.MDConfig`
#
# Public API notebook for **MDConfig**. This page only uses the supported public import path and intentionally omits internal implementation details.
#
# **Purpose:** Public dataclass `MDConfig`.

# %% [markdown]
# ## Installation
#
# Recommended installation for this API: `pip install 'zynnova[dynamics]'`.
#
# Run this notebook from an environment where ZynNova is installed. Expensive downloads, training, visualization, and simulations are disabled by default.

# %%
try:
    from zynnova.dynamics import MDConfig as API
except ImportError as exc:
    API = None
    print('Optional dependency or installation is missing:', exc)
else:
    print('Imported: zynnova.dynamics.MDConfig')

# %% [markdown]
# ## Signature
#
# ```python
# MDConfig(ensemble: Ensemble | str = Ensemble.NVE, steps: int = 1000, timestep_fs: float = 1.0, temperature_K: float | None = 300.0, pressure_GPa: float | None = None, friction_per_fs: float = 0.01, thermostat_time_fs: float = 100.0, barostat_time_fs: float = 1000.0, compressibility_GPa_inv: float = 4.57e-05, andersen_probability: float = 0.01, thermostat_chain_length: int = 3, barostat_chain_length: int = 3, thermostat_substeps: int = 1, barostat_substeps: int = 1, cell_mask: tuple[bool, bool, bool] = (True, True, True), pressure_mask: tuple[int, int, int] = (1, 1, 1), remove_com_interval: int = 0, random_seed: int | None = 0, extra_integrator_kwargs: dict[str, Any] = field(default_factory=dict))
# ```
#
# | Parameter | Type | Default | Required |
# |---|---|---|---|
# | `ensemble` | `Ensemble \| str` | `Ensemble.NVE` | no |
# | `steps` | `int` | `1000` | no |
# | `timestep_fs` | `float` | `1.0` | no |
# | `temperature_K` | `float \| None` | `300.0` | no |
# | `pressure_GPa` | `float \| None` | `None` | no |
# | `friction_per_fs` | `float` | `0.01` | no |
# | `thermostat_time_fs` | `float` | `100.0` | no |
# | `barostat_time_fs` | `float` | `1000.0` | no |
# | `compressibility_GPa_inv` | `float` | `4.57e-05` | no |
# | `andersen_probability` | `float` | `0.01` | no |
# | `thermostat_chain_length` | `int` | `3` | no |
# | `barostat_chain_length` | `int` | `3` | no |
# | `thermostat_substeps` | `int` | `1` | no |
# | `barostat_substeps` | `int` | `1` | no |
# | `cell_mask` | `tuple[bool, bool, bool]` | `(True, True, True)` | no |
# | `pressure_mask` | `tuple[int, int, int]` | `(1, 1, 1)` | no |
# | `remove_com_interval` | `int` | `0` | no |
# | `random_seed` | `int \| None` | `0` | no |
# | `extra_integrator_kwargs` | `dict[str, Any]` | `field(default_factory=dict)` | no |

# %%
import inspect

if API is not None:
    try:
        print(inspect.signature(API))
    except (TypeError, ValueError):
        print('This public object has no callable signature.')
    summary = (getattr(API, '__doc__', None) or '').strip()
    print(summary.split('\n\n', 1)[0] if summary else 'No public docstring.')

# %% [markdown]
# ## Minimal public usage
#
# The example below stays on the public API surface.

# %%
if API is not None:
    value = API()
    print(value)

# %% [markdown]
# ## Expected behavior and common failures
#
# - `ConfigurationError('steps must be non-negative')`
# - `ConfigurationError('timestep_fs must be positive')`
# - `ConfigurationError('thermostat_time_fs must be positive')`
# - `ConfigurationError('friction_per_fs must be non-negative')`
# - `ConfigurationError('andersen_probability must lie in [0, 1]')`
# - `ConfigurationError('cell_mask and pressure_mask must contain three values')`
# - `ConfigurationError(f'{self.ensemble.value} requires temperature_K > 0')`
# - `ConfigurationError(f'{self.ensemble.value} requires pressure_GPa')`
# - `ConfigurationError('barostat_time_fs must be positive')`
#
# For dataset downloads, model training, molecular dynamics, and external engines, first test with a small input and an explicit output directory.
