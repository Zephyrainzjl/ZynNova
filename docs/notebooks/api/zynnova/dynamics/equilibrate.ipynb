# %% [markdown]
# # `zynnova.dynamics.equilibrate`
#
# Public API notebook for **equilibrate**. This page only uses the supported public import path and intentionally omits internal implementation details.
#
# **Purpose:** Public function `equilibrate`.

# %% [markdown]
# ## Installation
#
# Recommended installation for this API: `pip install 'zynnova[dynamics]'`.
#
# Run this notebook from an environment where ZynNova is installed. Expensive downloads, training, visualization, and simulations are disabled by default.

# %%
try:
    from zynnova.dynamics import equilibrate as API
except ImportError as exc:
    API = None
    print('Optional dependency or installation is missing:', exc)
else:
    print('Imported: zynnova.dynamics.equilibrate')

# %% [markdown]
# ## Signature
#
# ```python
# equilibrate(structure: Any, calculator: Any, md_stages: list[MDConfig], *, relaxation: RelaxationConfig | None = None, output_directory: str | Path = 'zynnova-equilibration', base_config: RunConfig | None = None) -> WorkflowResult
# ```
#
# | Parameter | Type | Default | Required |
# |---|---|---|---|
# | `structure` | `Any` | `-` | yes |
# | `calculator` | `Any` | `-` | yes |
# | `md_stages` | `list[MDConfig]` | `-` | yes |
# | `relaxation` | `RelaxationConfig \| None` | `None` | no |
# | `output_directory` | `str \| Path` | `'zynnova-equilibration'` | no |
# | `base_config` | `RunConfig \| None` | `None` | no |

# %%
import inspect

if API is not None:
    try:
        print(inspect.signature(API))
    except (TypeError, ValueError):
        print('This public object has no callable signature.')
    summary = (getattr(API, '__doc__', None) or '').strip()
    print(summary.split('\n\n', 1)[0] if summary else 'No public docstring.')

# %% [markdown]
# ## Minimal public usage
#
# The example below stays on the public API surface.

# %%
RUN_EXAMPLE = False  # Set True after replacing placeholders with your data.

if API is not None and RUN_EXAMPLE:
    result = API(...)  # Signature: equilibrate(structure: Any, calculator: Any, md_stages: list[MDConfig], *, relaxation: RelaxationConfig | None = None, output_directory: str | Path = 'zynnova-equilibration', base_config: RunConfig | None = None) -> WorkflowResult
    print(result)

# %% [markdown]
# ## Expected behavior and common failures
#
# - `ValueError('md_stages cannot be empty')`
#
# For dataset downloads, model training, molecular dynamics, and external engines, first test with a small input and an explicit output directory.
