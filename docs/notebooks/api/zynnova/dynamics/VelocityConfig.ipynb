# %% [markdown]
# # `zynnova.dynamics.VelocityConfig`
#
# Public API notebook for **VelocityConfig**. This page only uses the supported public import path and intentionally omits internal implementation details.
#
# **Purpose:** Public dataclass `VelocityConfig`.

# %% [markdown]
# ## Installation
#
# Recommended installation for this API: `pip install 'zynnova[dynamics]'`.
#
# Run this notebook from an environment where ZynNova is installed. Expensive downloads, training, visualization, and simulations are disabled by default.

# %%
try:
    from zynnova.dynamics import VelocityConfig as API
except ImportError as exc:
    API = None
    print('Optional dependency or installation is missing:', exc)
else:
    print('Imported: zynnova.dynamics.VelocityConfig')

# %% [markdown]
# ## Signature
#
# ```python
# VelocityConfig(mode: VelocityMode | str = VelocityMode.MAXWELL_BOLTZMANN, temperature_K: float | None = None, force_temperature: bool = False, remove_translation: bool = True, remove_rotation: bool = False, preserve_temperature_after_cleanup: bool = True, seed: int | None = 0)
# ```
#
# | Parameter | Type | Default | Required |
# |---|---|---|---|
# | `mode` | `VelocityMode \| str` | `VelocityMode.MAXWELL_BOLTZMANN` | no |
# | `temperature_K` | `float \| None` | `None` | no |
# | `force_temperature` | `bool` | `False` | no |
# | `remove_translation` | `bool` | `True` | no |
# | `remove_rotation` | `bool` | `False` | no |
# | `preserve_temperature_after_cleanup` | `bool` | `True` | no |
# | `seed` | `int \| None` | `0` | no |

# %%
import inspect

if API is not None:
    try:
        print(inspect.signature(API))
    except (TypeError, ValueError):
        print('This public object has no callable signature.')
    summary = (getattr(API, '__doc__', None) or '').strip()
    print(summary.split('\n\n', 1)[0] if summary else 'No public docstring.')

# %% [markdown]
# ## Minimal public usage
#
# The example below stays on the public API surface.

# %%
if API is not None:
    value = API()
    print(value)

# %% [markdown]
# ## Expected behavior and common failures
#
# - `ConfigurationError('Maxwell-Boltzmann initialization requires a positive temperature')`
#
# For dataset downloads, model training, molecular dynamics, and external engines, first test with a small input and an explicit output directory.
