# %% [markdown]
# # `zynnova.dynamics.OutputConfig`
#
# Public API notebook for **OutputConfig**. This page only uses the supported public import path and intentionally omits internal implementation details.
#
# **Purpose:** Public dataclass `OutputConfig`.

# %% [markdown]
# ## Installation
#
# Recommended installation for this API: `pip install 'zynnova[dynamics]'`.
#
# Run this notebook from an environment where ZynNova is installed. Expensive downloads, training, visualization, and simulations are disabled by default.

# %%
try:
    from zynnova.dynamics import OutputConfig as API
except ImportError as exc:
    API = None
    print('Optional dependency or installation is missing:', exc)
else:
    print('Imported: zynnova.dynamics.OutputConfig')

# %% [markdown]
# ## Signature
#
# ```python
# OutputConfig(directory: str | Path = 'zynnova-md', trajectory_filename: str = 'trajectory.traj', thermo_filename: str = 'thermo.csv', metadata_filename: str = 'run.json', checkpoint_filename: str = 'checkpoint.traj', checkpoint_state_filename: str = 'checkpoint.json', trajectory_interval: int = 10, log_interval: int = 10, checkpoint_interval: int = 1000, append: bool = False, overwrite: bool = False, store_in_memory: bool = True)
# ```
#
# | Parameter | Type | Default | Required |
# |---|---|---|---|
# | `directory` | `str \| Path` | `'zynnova-md'` | no |
# | `trajectory_filename` | `str` | `'trajectory.traj'` | no |
# | `thermo_filename` | `str` | `'thermo.csv'` | no |
# | `metadata_filename` | `str` | `'run.json'` | no |
# | `checkpoint_filename` | `str` | `'checkpoint.traj'` | no |
# | `checkpoint_state_filename` | `str` | `'checkpoint.json'` | no |
# | `trajectory_interval` | `int` | `10` | no |
# | `log_interval` | `int` | `10` | no |
# | `checkpoint_interval` | `int` | `1000` | no |
# | `append` | `bool` | `False` | no |
# | `overwrite` | `bool` | `False` | no |
# | `store_in_memory` | `bool` | `True` | no |

# %%
import inspect

if API is not None:
    try:
        print(inspect.signature(API))
    except (TypeError, ValueError):
        print('This public object has no callable signature.')
    summary = (getattr(API, '__doc__', None) or '').strip()
    print(summary.split('\n\n', 1)[0] if summary else 'No public docstring.')

# %% [markdown]
# ## Minimal public usage
#
# The example below stays on the public API surface.

# %%
if API is not None:
    value = API()
    print(value)

# %% [markdown]
# ## Expected behavior and common failures
#
# - `ConfigurationError(f'{name} must be non-negative')`
#
# For dataset downloads, model training, molecular dynamics, and external engines, first test with a small input and an explicit output directory.
