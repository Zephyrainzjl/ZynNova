# %% [markdown]
# # `zynnova.dynamics.fix_atoms`
#
# Public API notebook for **fix_atoms**. This page only uses the supported public import path and intentionally omits internal implementation details.
#
# **Purpose:** Return an ASE structure with a ``FixAtoms`` constraint attached.

# %% [markdown]
# ## Installation
#
# Recommended installation for this API: `pip install 'zynnova[dynamics]'`.
#
# Run this notebook from an environment where ZynNova is installed. Expensive downloads, training, visualization, and simulations are disabled by default.

# %%
try:
    from zynnova.dynamics import fix_atoms as API
except ImportError as exc:
    API = None
    print('Optional dependency or installation is missing:', exc)
else:
    print('Imported: zynnova.dynamics.fix_atoms')

# %% [markdown]
# ## Signature
#
# ```python
# fix_atoms(structure: Any, *, indices: Iterable[int] | None = None, mask: Iterable[bool] | None = None, symbols: Iterable[str] | None = None, tags: Iterable[int] | None = None) -> Any
# ```
#
# | Parameter | Type | Default | Required |
# |---|---|---|---|
# | `structure` | `Any` | `-` | yes |
# | `indices` | `Iterable[int] \| None` | `None` | no |
# | `mask` | `Iterable[bool] \| None` | `None` | no |
# | `symbols` | `Iterable[str] \| None` | `None` | no |
# | `tags` | `Iterable[int] \| None` | `None` | no |

# %%
import inspect

if API is not None:
    try:
        print(inspect.signature(API))
    except (TypeError, ValueError):
        print('This public object has no callable signature.')
    summary = (getattr(API, '__doc__', None) or '').strip()
    print(summary.split('\n\n', 1)[0] if summary else 'No public docstring.')

# %% [markdown]
# ## Minimal public usage
#
# The example below stays on the public API surface.

# %%
RUN_EXAMPLE = False  # Set True after replacing placeholders with your data.

if API is not None and RUN_EXAMPLE:
    result = API(...)  # Signature: fix_atoms(structure: Any, *, indices: Iterable[int] | None = None, mask: Iterable[bool] | None = None, symbols: Iterable[str] | None = None, tags: Iterable[int] | None = None) -> Any
    print(result)

# %% [markdown]
# ## Expected behavior and common failures
#
# - `ValueError('No atoms were selected for fixing')`
# - `MissingBackendError('ASE constraints are required')`
# - `ValueError('mask must have one value per atom')`
#
# For dataset downloads, model training, molecular dynamics, and external engines, first test with a small input and an explicit output directory.
