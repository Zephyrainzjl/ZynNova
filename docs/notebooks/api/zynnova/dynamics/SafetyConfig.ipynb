# %% [markdown]
# # `zynnova.dynamics.SafetyConfig`
#
# Public API notebook for **SafetyConfig**. This page only uses the supported public import path and intentionally omits internal implementation details.
#
# **Purpose:** Public dataclass `SafetyConfig`.

# %% [markdown]
# ## Installation
#
# Recommended installation for this API: `pip install 'zynnova[dynamics]'`.
#
# Run this notebook from an environment where ZynNova is installed. Expensive downloads, training, visualization, and simulations are disabled by default.

# %%
try:
    from zynnova.dynamics import SafetyConfig as API
except ImportError as exc:
    API = None
    print('Optional dependency or installation is missing:', exc)
else:
    print('Imported: zynnova.dynamics.SafetyConfig')

# %% [markdown]
# ## Signature
#
# ```python
# SafetyConfig(check_interval: int = 10, stop_on_nonfinite: bool = True, max_force_eV_per_A: float | None = 10000.0, max_temperature_K: float | None = 1000000.0, min_temperature_K: float | None = None, minimum_distance_A: float | None = 0.2, max_energy_per_atom_eV: float | None = 1000000.0, max_energy_jump_per_atom_eV: float | None = 10000.0, min_volume_A3: float | None = 1e-06, wrap_positions: bool = False)
# ```
#
# | Parameter | Type | Default | Required |
# |---|---|---|---|
# | `check_interval` | `int` | `10` | no |
# | `stop_on_nonfinite` | `bool` | `True` | no |
# | `max_force_eV_per_A` | `float \| None` | `10000.0` | no |
# | `max_temperature_K` | `float \| None` | `1000000.0` | no |
# | `min_temperature_K` | `float \| None` | `None` | no |
# | `minimum_distance_A` | `float \| None` | `0.2` | no |
# | `max_energy_per_atom_eV` | `float \| None` | `1000000.0` | no |
# | `max_energy_jump_per_atom_eV` | `float \| None` | `10000.0` | no |
# | `min_volume_A3` | `float \| None` | `1e-06` | no |
# | `wrap_positions` | `bool` | `False` | no |

# %%
import inspect

if API is not None:
    try:
        print(inspect.signature(API))
    except (TypeError, ValueError):
        print('This public object has no callable signature.')
    summary = (getattr(API, '__doc__', None) or '').strip()
    print(summary.split('\n\n', 1)[0] if summary else 'No public docstring.')

# %% [markdown]
# ## Minimal public usage
#
# The example below stays on the public API surface.

# %%
if API is not None:
    value = API()
    print(value)

# %% [markdown]
# ## Expected behavior and common failures
#
# - `ConfigurationError('safety check_interval must be positive')`
# - `ConfigurationError(f'{name} must be positive when provided')`
#
# For dataset downloads, model training, molecular dynamics, and external engines, first test with a small input and an explicit output directory.
