# %% [markdown]
# # `zynnova.dynamics.RelaxationConfig`
#
# Public API notebook for **RelaxationConfig**. This page only uses the supported public import path and intentionally omits internal implementation details.
#
# **Purpose:** Public dataclass `RelaxationConfig`.

# %% [markdown]
# ## Installation
#
# Recommended installation for this API: `pip install 'zynnova[dynamics]'`.
#
# Run this notebook from an environment where ZynNova is installed. Expensive downloads, training, visualization, and simulations are disabled by default.

# %%
try:
    from zynnova.dynamics import RelaxationConfig as API
except ImportError as exc:
    API = None
    print('Optional dependency or installation is missing:', exc)
else:
    print('Imported: zynnova.dynamics.RelaxationConfig')

# %% [markdown]
# ## Signature
#
# ```python
# RelaxationConfig(optimizer: OptimizerMethod | str = OptimizerMethod.FIRE2, cell_mode: CellMode | str = CellMode.FIXED, fmax_eV_per_A: float = 0.05, smax_eV_per_A3: float = 0.005, max_steps: int = 1000, maxstep_A: float = 0.2, restart_filename: str | None = None, trajectory_filename: str | None = 'relaxation.traj', logfile: str | None = 'relaxation.log', append_trajectory: bool = False, cell_mask: tuple[bool, bool, bool, bool, bool, bool] = (True, True, True, True, True, True), hydrostatic_strain: bool = False, constant_volume: bool = False, scalar_pressure_GPa: float = 0.0, optimizer_kwargs: dict[str, Any] = field(default_factory=dict), filter_kwargs: dict[str, Any] = field(default_factory=dict))
# ```
#
# | Parameter | Type | Default | Required |
# |---|---|---|---|
# | `optimizer` | `OptimizerMethod \| str` | `OptimizerMethod.FIRE2` | no |
# | `cell_mode` | `CellMode \| str` | `CellMode.FIXED` | no |
# | `fmax_eV_per_A` | `float` | `0.05` | no |
# | `smax_eV_per_A3` | `float` | `0.005` | no |
# | `max_steps` | `int` | `1000` | no |
# | `maxstep_A` | `float` | `0.2` | no |
# | `restart_filename` | `str \| None` | `None` | no |
# | `trajectory_filename` | `str \| None` | `'relaxation.traj'` | no |
# | `logfile` | `str \| None` | `'relaxation.log'` | no |
# | `append_trajectory` | `bool` | `False` | no |
# | `cell_mask` | `tuple[bool, bool, bool, bool, bool, bool]` | `(True, True, True, True, True, True)` | no |
# | `hydrostatic_strain` | `bool` | `False` | no |
# | `constant_volume` | `bool` | `False` | no |
# | `scalar_pressure_GPa` | `float` | `0.0` | no |
# | `optimizer_kwargs` | `dict[str, Any]` | `field(default_factory=dict)` | no |
# | `filter_kwargs` | `dict[str, Any]` | `field(default_factory=dict)` | no |

# %%
import inspect

if API is not None:
    try:
        print(inspect.signature(API))
    except (TypeError, ValueError):
        print('This public object has no callable signature.')
    summary = (getattr(API, '__doc__', None) or '').strip()
    print(summary.split('\n\n', 1)[0] if summary else 'No public docstring.')

# %% [markdown]
# ## Minimal public usage
#
# The example below stays on the public API surface.

# %%
if API is not None:
    value = API()
    print(value)

# %% [markdown]
# ## Expected behavior and common failures
#
# - `ConfigurationError('fmax_eV_per_A must be positive')`
# - `ConfigurationError('smax_eV_per_A3 must be positive')`
# - `ConfigurationError('max_steps must be positive')`
# - `ConfigurationError('maxstep_A must be positive')`
# - `ConfigurationError('cell_mask must have six Voigt components')`
#
# For dataset downloads, model training, molecular dynamics, and external engines, first test with a small input and an explicit output directory.
