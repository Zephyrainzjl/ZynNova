# %% [markdown]
# # `zynnova.data.DataPipeline`
#
# Public API notebook for **DataPipeline**. This page only uses the supported public import path and intentionally omits internal implementation details.
#
# **Purpose:** Composable source -> transforms -> task -> Torch/storage pipeline.

# %% [markdown]
# ## Installation
#
# Recommended installation for this API: `pip install 'zynnova[data-all]'`.
#
# Run this notebook from an environment where ZynNova is installed. Expensive downloads, training, visualization, and simulations are disabled by default.

# %%
try:
    from zynnova.data import DataPipeline as API
except ImportError as exc:
    API = None
    print('Optional dependency or installation is missing:', exc)
else:
    print('Imported: zynnova.data.DataPipeline')

# %% [markdown]
# ## Signature
#
# ```python
# DataPipeline(source: DatasetSource | Sequence[MaterialSample] | Iterable[MaterialSample], transforms: Compose | None = None, representation_schema: Any | None = None, _materialized: list[MaterialSample] | None = field(default=None, init=False, repr=False))
# ```
#
# | Parameter | Type | Default | Required |
# |---|---|---|---|
# | `source` | `DatasetSource \| Sequence[MaterialSample] \| Iterable[MaterialSample]` | `-` | yes |
# | `transforms` | `Compose \| None` | `None` | no |
# | `representation_schema` | `Any \| None` | `None` | no |
# | `_materialized` | `list[MaterialSample] \| None` | `field(default=None, init=False, repr=False)` | no |

# %%
import inspect

if API is not None:
    try:
        print(inspect.signature(API))
    except (TypeError, ValueError):
        print('This public object has no callable signature.')
    summary = (getattr(API, '__doc__', None) or '').strip()
    print(summary.split('\n\n', 1)[0] if summary else 'No public docstring.')

# %% [markdown]
# ## Minimal public usage
#
# The example below stays on the public API surface.

# %%
RUN_EXAMPLE = False  # Set True after supplying the required constructor values.

if API is not None and RUN_EXAMPLE:
    value = API(...)  # Signature: DataPipeline(source: DatasetSource | Sequence[MaterialSample] | Iterable[MaterialSample], transforms: Compose | None = None, representation_schema: Any | None = None, _materialized: list[MaterialSample] | None = field(default=None, init=False, repr=False))
    print(value)

# %% [markdown]
# ## Expected behavior and common failures
#
# - `ValueError('representation schema fitting requires polymer records')`
#
# For dataset downloads, model training, molecular dynamics, and external engines, first test with a small input and an explicit output directory.
