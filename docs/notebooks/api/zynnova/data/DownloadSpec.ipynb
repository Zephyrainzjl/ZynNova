# %% [markdown]
# # `zynnova.data.DownloadSpec`
#
# Public API notebook for **DownloadSpec**. This page only uses the supported public import path and intentionally omits internal implementation details.
#
# **Purpose:** Public dataclass `DownloadSpec`.

# %% [markdown]
# ## Installation
#
# Recommended installation for this API: `pip install 'zynnova[data-all]'`.
#
# Run this notebook from an environment where ZynNova is installed. Expensive downloads, training, visualization, and simulations are disabled by default.

# %%
try:
    from zynnova.data import DownloadSpec as API
except ImportError as exc:
    API = None
    print('Optional dependency or installation is missing:', exc)
else:
    print('Imported: zynnova.data.DownloadSpec')

# %% [markdown]
# ## Signature
#
# ```python
# DownloadSpec(urls: tuple[str, ...], filename: str, checksum: str | None = None, checksum_algorithm: str = 'sha256', archive: str | None = 'auto', extract: bool = False, extract_subdir: str | None = None, headers: Mapping[str, str] = field(default_factory=dict), description: str | None = None)
# ```
#
# | Parameter | Type | Default | Required |
# |---|---|---|---|
# | `urls` | `tuple[str, ...]` | `-` | yes |
# | `filename` | `str` | `-` | yes |
# | `checksum` | `str \| None` | `None` | no |
# | `checksum_algorithm` | `str` | `'sha256'` | no |
# | `archive` | `str \| None` | `'auto'` | no |
# | `extract` | `bool` | `False` | no |
# | `extract_subdir` | `str \| None` | `None` | no |
# | `headers` | `Mapping[str, str]` | `field(default_factory=dict)` | no |
# | `description` | `str \| None` | `None` | no |

# %%
import inspect

if API is not None:
    try:
        print(inspect.signature(API))
    except (TypeError, ValueError):
        print('This public object has no callable signature.')
    summary = (getattr(API, '__doc__', None) or '').strip()
    print(summary.split('\n\n', 1)[0] if summary else 'No public docstring.')

# %% [markdown]
# ## Minimal public usage
#
# The example below stays on the public API surface.

# %%
RUN_EXAMPLE = False  # Set True after supplying the required constructor values.

if API is not None and RUN_EXAMPLE:
    value = API(...)  # Signature: DownloadSpec(urls: tuple[str, ...], filename: str, checksum: str | None = None, checksum_algorithm: str = 'sha256', archive: str | None = 'auto', extract: bool = False, extract_subdir: str | None = None, headers: Mapping[str, str] = field(default_factory=dict), description: str | None = None)
    print(value)

# %% [markdown]
# ## Expected behavior and common failures
#
# - `ValueError('DownloadSpec.urls cannot be empty')`
# - `ValueError('filename must be a basename')`
#
# For dataset downloads, model training, molecular dynamics, and external engines, first test with a small input and an explicit output directory.
