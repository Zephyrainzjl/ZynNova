# %% [markdown]
# # `zynnova.data.FieldSpec`
#
# Public API notebook for **FieldSpec**. This page only uses the supported public import path and intentionally omits internal implementation details.
#
# **Purpose:** Description of one freely selectable model field.

# %% [markdown]
# ## Installation
#
# Recommended installation for this API: `pip install 'zynnova[data-all]'`.
#
# Run this notebook from an environment where ZynNova is installed. Expensive downloads, training, visualization, and simulations are disabled by default.

# %%
try:
    from zynnova.data import FieldSpec as API
except ImportError as exc:
    API = None
    print('Optional dependency or installation is missing:', exc)
else:
    print('Imported: zynnova.data.FieldSpec')

# %% [markdown]
# ## Signature
#
# ```python
# FieldSpec(name: str, source: str, role: FieldRole | str = FieldRole.FEATURE, level: FieldLevel | str = FieldLevel.GRAPH, dtype: str | None = None, unit: str | None = None, shape: tuple[int | None, ...] | None = None, required: bool = True, missing: MissingPolicy | str = MissingPolicy.ERROR, fill_value: Any = 0.0, normalize: bool = False)
# ```
#
# | Parameter | Type | Default | Required |
# |---|---|---|---|
# | `name` | `str` | `-` | yes |
# | `source` | `str` | `-` | yes |
# | `role` | `FieldRole \| str` | `FieldRole.FEATURE` | no |
# | `level` | `FieldLevel \| str` | `FieldLevel.GRAPH` | no |
# | `dtype` | `str \| None` | `None` | no |
# | `unit` | `str \| None` | `None` | no |
# | `shape` | `tuple[int \| None, ...] \| None` | `None` | no |
# | `required` | `bool` | `True` | no |
# | `missing` | `MissingPolicy \| str` | `MissingPolicy.ERROR` | no |
# | `fill_value` | `Any` | `0.0` | no |
# | `normalize` | `bool` | `False` | no |

# %%
import inspect

if API is not None:
    try:
        print(inspect.signature(API))
    except (TypeError, ValueError):
        print('This public object has no callable signature.')
    summary = (getattr(API, '__doc__', None) or '').strip()
    print(summary.split('\n\n', 1)[0] if summary else 'No public docstring.')

# %% [markdown]
# ## Minimal public usage
#
# The example below stays on the public API surface.

# %%
RUN_EXAMPLE = False  # Set True after supplying the required constructor values.

if API is not None and RUN_EXAMPLE:
    value = API(...)  # Signature: FieldSpec(name: str, source: str, role: FieldRole | str = FieldRole.FEATURE, level: FieldLevel | str = FieldLevel.GRAPH, dtype: str | None = None, unit: str | None = None, shape: tuple[int | None, ...] | None = None, required: bool = True, missing: MissingPolicy | str = MissingPolicy.ERROR, fill_value: Any = 0.0, normalize: bool = False)
    print(value)

# %% [markdown]
# ## Expected behavior and common failures
#
# - `SchemaError(f'required field {self.name!r} ({self.source}) is missing in sample {sample.id!r}')`
# - `ValueError('field name cannot be empty')`
# - `ValueError('field source cannot be empty')`
#
# For dataset downloads, model training, molecular dynamics, and external engines, first test with a small input and an explicit output directory.
