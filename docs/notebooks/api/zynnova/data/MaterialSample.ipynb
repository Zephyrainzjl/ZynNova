# %% [markdown]
# # `zynnova.data.MaterialSample`
#
# Public API notebook for **MaterialSample**. This page only uses the supported public import path and intentionally omits internal implementation details.
#
# **Purpose:** Unified sample exchanged between dataset plugins and model encoders.

# %% [markdown]
# ## Installation
#
# Recommended installation for this API: `pip install 'zynnova[data-all]'`.
#
# Run this notebook from an environment where ZynNova is installed. Expensive downloads, training, visualization, and simulations are disabled by default.

# %%
try:
    from zynnova.data import MaterialSample as API
except ImportError as exc:
    API = None
    print('Optional dependency or installation is missing:', exc)
else:
    print('Imported: zynnova.data.MaterialSample')

# %% [markdown]
# ## Signature
#
# ```python
# MaterialSample(id: str, material_type: MaterialType | str, structure: Any | None = None, features: dict[str, Any] = field(default_factory=dict), labels: dict[str, Any] = field(default_factory=dict), conditions: dict[str, Any] = field(default_factory=dict), metadata: dict[str, Any] = field(default_factory=dict), provenance: dict[str, Any] = field(default_factory=dict), split: str | None = None)
# ```
#
# | Parameter | Type | Default | Required |
# |---|---|---|---|
# | `id` | `str` | `-` | yes |
# | `material_type` | `MaterialType \| str` | `-` | yes |
# | `structure` | `Any \| None` | `None` | no |
# | `features` | `dict[str, Any]` | `field(default_factory=dict)` | no |
# | `labels` | `dict[str, Any]` | `field(default_factory=dict)` | no |
# | `conditions` | `dict[str, Any]` | `field(default_factory=dict)` | no |
# | `metadata` | `dict[str, Any]` | `field(default_factory=dict)` | no |
# | `provenance` | `dict[str, Any]` | `field(default_factory=dict)` | no |
# | `split` | `str \| None` | `None` | no |

# %%
import inspect

if API is not None:
    try:
        print(inspect.signature(API))
    except (TypeError, ValueError):
        print('This public object has no callable signature.')
    summary = (getattr(API, '__doc__', None) or '').strip()
    print(summary.split('\n\n', 1)[0] if summary else 'No public docstring.')

# %% [markdown]
# ## Minimal public usage
#
# The example below stays on the public API surface.

# %%
RUN_EXAMPLE = False  # Set True after supplying the required constructor values.

if API is not None and RUN_EXAMPLE:
    value = API(...)  # Signature: MaterialSample(id: str, material_type: MaterialType | str, structure: Any | None = None, features: dict[str, Any] = field(default_factory=dict), labels: dict[str, Any] = field(default_factory=dict), conditions: dict[str, Any] = field(default_factory=dict), metadata: dict[str, Any] = field(default_factory=dict), provenance: dict[str, Any] = field(default_factory=dict), split: str | None = None)
    print(value)

# %% [markdown]
# ## Expected behavior and common failures
#
# - `SchemaError(f'sample {self.id!r} has no field {path!r}')`
# - `ValueError(f'mutable field root is not supported: {root!r}')`
# - `ValueError('set() requires a nested path such as features.foo')`
# - `TypeError(f'cannot descend through non-mapping field {part!r}')`
#
# For dataset downloads, model training, molecular dynamics, and external engines, first test with a small input and an explicit output directory.
