# %% [markdown]
# # `zynnova.data.compile_sample`
#
# Public API notebook for **compile_sample**. This page only uses the supported public import path and intentionally omits internal implementation details.
#
# **Purpose:** Public function `compile_sample`.

# %% [markdown]
# ## Installation
#
# Recommended installation for this API: `pip install 'zynnova[data-all]'`.
#
# Run this notebook from an environment where ZynNova is installed. Expensive downloads, training, visualization, and simulations are disabled by default.

# %%
try:
    from zynnova.data import compile_sample as API
except ImportError as exc:
    API = None
    print('Optional dependency or installation is missing:', exc)
else:
    print('Imported: zynnova.data.compile_sample')

# %% [markdown]
# ## Signature
#
# ```python
# compile_sample(sample: MaterialSample, task: TaskSpec, *, representation_schema: Any | None = None, tensorize: bool = True) -> CompiledSample
# ```
#
# | Parameter | Type | Default | Required |
# |---|---|---|---|
# | `sample` | `MaterialSample` | `-` | yes |
# | `task` | `TaskSpec` | `-` | yes |
# | `representation_schema` | `Any \| None` | `None` | no |
# | `tensorize` | `bool` | `True` | no |

# %%
import inspect

if API is not None:
    try:
        print(inspect.signature(API))
    except (TypeError, ValueError):
        print('This public object has no callable signature.')
    summary = (getattr(API, '__doc__', None) or '').strip()
    print(summary.split('\n\n', 1)[0] if summary else 'No public docstring.')

# %% [markdown]
# ## Minimal public usage
#
# The example below stays on the public API surface.

# %%
RUN_EXAMPLE = False  # Set True after replacing placeholders with your data.

if API is not None and RUN_EXAMPLE:
    result = API(...)  # Signature: compile_sample(sample: MaterialSample, task: TaskSpec, *, representation_schema: Any | None = None, tensorize: bool = True) -> CompiledSample
    print(result)

# %% [markdown]
# ## Expected behavior and common failures
#
# - `SchemaError(f'sample {sample.id!r} was rejected by task {task.name!r}')`
#
# For dataset downloads, model training, molecular dynamics, and external engines, first test with a small input and an explicit output directory.
