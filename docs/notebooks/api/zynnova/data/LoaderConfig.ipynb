# %% [markdown]
# # `zynnova.data.LoaderConfig`
#
# Public API notebook for **LoaderConfig**. This page only uses the supported public import path and intentionally omits internal implementation details.
#
# **Purpose:** Public dataclass `LoaderConfig`.

# %% [markdown]
# ## Installation
#
# Recommended installation for this API: `pip install 'zynnova[data-all]'`.
#
# Run this notebook from an environment where ZynNova is installed. Expensive downloads, training, visualization, and simulations are disabled by default.

# %%
try:
    from zynnova.data import LoaderConfig as API
except ImportError as exc:
    API = None
    print('Optional dependency or installation is missing:', exc)
else:
    print('Imported: zynnova.data.LoaderConfig')

# %% [markdown]
# ## Signature
#
# ```python
# LoaderConfig(batch_size: int = 32, shuffle: bool = True, num_workers: int = 0, pin_memory: bool = False, drop_last: bool = False, persistent_workers: bool = False, prefetch_factor: int | None = None, timeout: float = 0.0, sampler: Any | None = None, batch_sampler: Any | None = None, collate_fn: Any | None = None, worker_init_fn: Any | None = None, seed: int = 0)
# ```
#
# | Parameter | Type | Default | Required |
# |---|---|---|---|
# | `batch_size` | `int` | `32` | no |
# | `shuffle` | `bool` | `True` | no |
# | `num_workers` | `int` | `0` | no |
# | `pin_memory` | `bool` | `False` | no |
# | `drop_last` | `bool` | `False` | no |
# | `persistent_workers` | `bool` | `False` | no |
# | `prefetch_factor` | `int \| None` | `None` | no |
# | `timeout` | `float` | `0.0` | no |
# | `sampler` | `Any \| None` | `None` | no |
# | `batch_sampler` | `Any \| None` | `None` | no |
# | `collate_fn` | `Any \| None` | `None` | no |
# | `worker_init_fn` | `Any \| None` | `None` | no |
# | `seed` | `int` | `0` | no |

# %%
import inspect

if API is not None:
    try:
        print(inspect.signature(API))
    except (TypeError, ValueError):
        print('This public object has no callable signature.')
    summary = (getattr(API, '__doc__', None) or '').strip()
    print(summary.split('\n\n', 1)[0] if summary else 'No public docstring.')

# %% [markdown]
# ## Minimal public usage
#
# The example below stays on the public API surface.

# %%
if API is not None:
    value = API()
    print(value)

# %% [markdown]
# ## Expected behavior and common failures
#
# - Validate shapes, units, optional dependencies, and output paths before production use.
#
# For dataset downloads, model training, molecular dynamics, and external engines, first test with a small input and an explicit output directory.
