# %% [markdown]
# # `zynnova.data.fit_field_statistics`
#
# Public API notebook for **fit_field_statistics**. This page only uses the supported public import path and intentionally omits internal implementation details.
#
# **Purpose:** Fit scalar standardization statistics using a stable online algorithm.

# %% [markdown]
# ## Installation
#
# Recommended installation for this API: `pip install 'zynnova[data-all]'`.
#
# Run this notebook from an environment where ZynNova is installed. Expensive downloads, training, visualization, and simulations are disabled by default.

# %%
try:
    from zynnova.data import fit_field_statistics as API
except ImportError as exc:
    API = None
    print('Optional dependency or installation is missing:', exc)
else:
    print('Imported: zynnova.data.fit_field_statistics')

# %% [markdown]
# ## Signature
#
# ```python
# fit_field_statistics(samples: Iterable[MaterialSample], fields: Sequence[str], *, ignore_non_finite: bool = True) -> dict[str, FieldStatistics]
# ```
#
# | Parameter | Type | Default | Required |
# |---|---|---|---|
# | `samples` | `Iterable[MaterialSample]` | `-` | yes |
# | `fields` | `Sequence[str]` | `-` | yes |
# | `ignore_non_finite` | `bool` | `True` | no |

# %%
import inspect

if API is not None:
    try:
        print(inspect.signature(API))
    except (TypeError, ValueError):
        print('This public object has no callable signature.')
    summary = (getattr(API, '__doc__', None) or '').strip()
    print(summary.split('\n\n', 1)[0] if summary else 'No public docstring.')

# %% [markdown]
# ## Minimal public usage
#
# The example below stays on the public API surface.

# %%
RUN_EXAMPLE = False  # Set True after replacing placeholders with your data.

if API is not None and RUN_EXAMPLE:
    result = API(...)  # Signature: fit_field_statistics(samples: Iterable[MaterialSample], fields: Sequence[str], *, ignore_non_finite: bool = True) -> dict[str, FieldStatistics]
    print(result)

# %% [markdown]
# ## Expected behavior and common failures
#
# - `ValueError(f'cannot fit statistics for empty field {path!r}')`
#
# For dataset downloads, model training, molecular dynamics, and external engines, first test with a small input and an explicit output directory.
