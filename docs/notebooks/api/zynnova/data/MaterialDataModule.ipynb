# %% [markdown]
# # `zynnova.data.MaterialDataModule`
#
# Public API notebook for **MaterialDataModule**. This page only uses the supported public import path and intentionally omits internal implementation details.
#
# **Purpose:** Public dataclass `MaterialDataModule`.

# %% [markdown]
# ## Installation
#
# Recommended installation for this API: `pip install 'zynnova[data-all]'`.
#
# Run this notebook from an environment where ZynNova is installed. Expensive downloads, training, visualization, and simulations are disabled by default.

# %%
try:
    from zynnova.data import MaterialDataModule as API
except ImportError as exc:
    API = None
    print('Optional dependency or installation is missing:', exc)
else:
    print('Imported: zynnova.data.MaterialDataModule')

# %% [markdown]
# ## Signature
#
# ```python
# MaterialDataModule(source: DatasetSource | Sequence[MaterialSample], compiler: TaskCompiler, loader: LoaderConfig = field(default_factory=LoaderConfig), transforms: Compose | None = None, ratios: tuple[float, float, float] = (0.8, 0.1, 0.1), split_indices: dict[str, Any] | None = None, streaming: bool = False, _datasets: dict[str, Any] = field(init=False, default_factory=dict, repr=False))
# ```
#
# | Parameter | Type | Default | Required |
# |---|---|---|---|
# | `source` | `DatasetSource \| Sequence[MaterialSample]` | `-` | yes |
# | `compiler` | `TaskCompiler` | `-` | yes |
# | `loader` | `LoaderConfig` | `field(default_factory=LoaderConfig)` | no |
# | `transforms` | `Compose \| None` | `None` | no |
# | `ratios` | `tuple[float, float, float]` | `(0.8, 0.1, 0.1)` | no |
# | `split_indices` | `dict[str, Any] \| None` | `None` | no |
# | `streaming` | `bool` | `False` | no |
# | `_datasets` | `dict[str, Any]` | `field(init=False, default_factory=dict, repr=False)` | no |

# %%
import inspect

if API is not None:
    try:
        print(inspect.signature(API))
    except (TypeError, ValueError):
        print('This public object has no callable signature.')
    summary = (getattr(API, '__doc__', None) or '').strip()
    print(summary.split('\n\n', 1)[0] if summary else 'No public docstring.')

# %% [markdown]
# ## Minimal public usage
#
# The example below stays on the public API surface.

# %%
RUN_EXAMPLE = False  # Set True after supplying the required constructor values.

if API is not None and RUN_EXAMPLE:
    value = API(...)  # Signature: MaterialDataModule(source: DatasetSource | Sequence[MaterialSample], compiler: TaskCompiler, loader: LoaderConfig = field(default_factory=LoaderConfig), transforms: Compose | None = None, ratios: tuple[float, float, float] = (0.8, 0.1, 0.1), split_indices: dict[str, Any] | None = None, streaming: bool = False, _datasets: dict[str, Any] = field(init=False, default_factory=dict, repr=False))
    print(value)

# %% [markdown]
# ## Expected behavior and common failures
#
# - `ImportError('PyTorch is required; install zynnova[data]')`
#
# For dataset downloads, model training, molecular dynamics, and external engines, first test with a small input and an explicit output directory.
