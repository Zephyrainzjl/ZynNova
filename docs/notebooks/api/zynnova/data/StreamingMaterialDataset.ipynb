# %% [markdown]
# # `zynnova.data.StreamingMaterialDataset`
#
# Public API notebook for **StreamingMaterialDataset**. This page only uses the supported public import path and intentionally omits internal implementation details.
#
# **Purpose:** Worker-aware streaming dataset for APIs, shards and very large files.

# %% [markdown]
# ## Installation
#
# Recommended installation for this API: `pip install 'zynnova[data-all]'`.
#
# Run this notebook from an environment where ZynNova is installed. Expensive downloads, training, visualization, and simulations are disabled by default.

# %%
try:
    from zynnova.data import StreamingMaterialDataset as API
except ImportError as exc:
    API = None
    print('Optional dependency or installation is missing:', exc)
else:
    print('Imported: zynnova.data.StreamingMaterialDataset')

# %% [markdown]
# ## Signature
#
# ```python
# StreamingMaterialDataset(source: DatasetSource | Iterable[MaterialSample], compiler: TaskCompiler, *, transforms: Compose | None = None, split: str | None = None)
# ```
#
# | Parameter | Type | Default | Required |
# |---|---|---|---|
# | `source` | `DatasetSource \| Iterable[MaterialSample]` | `-` | yes |
# | `compiler` | `TaskCompiler` | `-` | yes |
# | `transforms` | `Compose \| None` | `None` | no |
# | `split` | `str \| None` | `None` | no |

# %%
import inspect

if API is not None:
    try:
        print(inspect.signature(API))
    except (TypeError, ValueError):
        print('This public object has no callable signature.')
    summary = (getattr(API, '__doc__', None) or '').strip()
    print(summary.split('\n\n', 1)[0] if summary else 'No public docstring.')

# %% [markdown]
# ## Minimal public usage
#
# The example below stays on the public API surface.

# %%
RUN_EXAMPLE = False  # Set True after supplying the required constructor values.

if API is not None and RUN_EXAMPLE:
    value = API(...)  # Signature: StreamingMaterialDataset(source: DatasetSource | Iterable[MaterialSample], compiler: TaskCompiler, *, transforms: Compose | None = None, split: str | None = None)
    print(value)

# %% [markdown]
# ## Expected behavior and common failures
#
# - Validate shapes, units, optional dependencies, and output paths before production use.
#
# For dataset downloads, model training, molecular dynamics, and external engines, first test with a small input and an explicit output directory.
