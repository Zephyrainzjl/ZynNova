# %% [markdown]
# # `zynnova.visualization.visualize_crystal`
#
# Public API notebook for **visualize_crystal**. This page only uses the supported public import path and intentionally omits internal implementation details.
#
# **Purpose:** Interactively display a periodic crystal, supercell, or trajectory.

# %% [markdown]
# ## Installation
#
# Recommended installation for this API: `pip install 'zynnova[visualization]'`.
#
# Run this notebook from an environment where ZynNova is installed. Expensive downloads, training, visualization, and simulations are disabled by default.

# %%
try:
    from zynnova.visualization import visualize_crystal as API
except ImportError as exc:
    API = None
    print('Optional dependency or installation is missing:', exc)
else:
    print('Imported: zynnova.visualization.visualize_crystal')

# %% [markdown]
# ## Signature
#
# ```python
# visualize_crystal(source: Any, *, backend: str = 'auto', style: str = 'ball_and_stick', supercell: tuple[int, int, int] = (1, 1, 1), show_unit_cell: bool = True, show_axes: bool = True, width: int = 800, height: int = 560, background: str = 'white', camera: str = 'orthographic', atom_labels: bool = False, atom_indices: bool = False, spin: bool = False, trajectory: bool = False, interval: int = 100, loop: str = 'forward', reps: int = 0, initial_frame: int = 0, format: str | None = None, **kwargs: Any) -> Any
# ```
#
# | Parameter | Type | Default | Required |
# |---|---|---|---|
# | `source` | `Any` | `-` | yes |
# | `backend` | `str` | `'auto'` | no |
# | `style` | `str` | `'ball_and_stick'` | no |
# | `supercell` | `tuple[int, int, int]` | `(1, 1, 1)` | no |
# | `show_unit_cell` | `bool` | `True` | no |
# | `show_axes` | `bool` | `True` | no |
# | `width` | `int` | `800` | no |
# | `height` | `int` | `560` | no |
# | `background` | `str` | `'white'` | no |
# | `camera` | `str` | `'orthographic'` | no |
# | `atom_labels` | `bool` | `False` | no |
# | `atom_indices` | `bool` | `False` | no |
# | `spin` | `bool` | `False` | no |
# | `trajectory` | `bool` | `False` | no |
# | `interval` | `int` | `100` | no |
# | `loop` | `str` | `'forward'` | no |
# | `reps` | `int` | `0` | no |
# | `initial_frame` | `int` | `0` | no |
# | `format` | `str \| None` | `None` | no |
# | `**kwargs` | `Any` | `-` | no |

# %%
import inspect

if API is not None:
    try:
        print(inspect.signature(API))
    except (TypeError, ValueError):
        print('This public object has no callable signature.')
    summary = (getattr(API, '__doc__', None) or '').strip()
    print(summary.split('\n\n', 1)[0] if summary else 'No public docstring.')

# %% [markdown]
# ## Minimal public usage
#
# The example below stays on the public API surface.

# %%
RUN_EXAMPLE = False  # Set True after replacing placeholders with your data.

if API is not None and RUN_EXAMPLE:
    result = API(...)  # Signature: visualize_crystal(source: Any, *, backend: str = 'auto', style: str = 'ball_and_stick', supercell: tuple[int, int, int] = (1, 1, 1), show_unit_cell: bool = True, show_axes: bool = True, width: int = 800, height: int = 560, background: str = 'white', camera: str = 'orthographic', atom_labels: bool = False, atom_indices: bool = False, spin: bool = False, trajectory: bool = False, interval: int = 100, loop: str = 'forward', reps: int = 0, initial_frame: int = 0, format: str | None = None, **kwargs: Any) -> Any
    print(result)

# %% [markdown]
# ## Expected behavior and common failures
#
# - `ValueError('crystal visualization requires periodic boundary conditions')`
#
# For dataset downloads, model training, molecular dynamics, and external engines, first test with a small input and an explicit output directory.
