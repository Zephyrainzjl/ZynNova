# %% [markdown]
# # `zynnova.visualization.ViewerConfig`
#
# Public API notebook for **ViewerConfig**. This page only uses the supported public import path and intentionally omits internal implementation details.
#
# **Purpose:** Common rendering configuration shared by all structure visualizers.

# %% [markdown]
# ## Installation
#
# Recommended installation for this API: `pip install 'zynnova[visualization]'`.
#
# Run this notebook from an environment where ZynNova is installed. Expensive downloads, training, visualization, and simulations are disabled by default.

# %%
try:
    from zynnova.visualization import ViewerConfig as API
except ImportError as exc:
    API = None
    print('Optional dependency or installation is missing:', exc)
else:
    print('Imported: zynnova.visualization.ViewerConfig')

# %% [markdown]
# ## Signature
#
# ```python
# ViewerConfig(width: int = 800, height: int = 500, background: str = 'white', style: RenderStyle = 'ball_and_stick', backend: BackendName = 'auto', camera: Literal['perspective', 'orthographic'] = 'perspective', spin: bool = False, atom_labels: bool = False, atom_indices: bool = False, show_hydrogens: bool = True, show_bonds: bool = True, show_unit_cell: bool = True, show_axes: bool = False, supercell: tuple[int, int, int] = (1, 1, 1), sphere_scale: float = 0.28, stick_radius: float = 0.16, line_width: float = 1.5, surface_opacity: float = 0.45, zoom: float = 1.0, color_by: Literal['element', 'unit', 'role', 'chain'] = 'element', metadata: dict[str, Any] = field(default_factory=dict))
# ```
#
# | Parameter | Type | Default | Required |
# |---|---|---|---|
# | `width` | `int` | `800` | no |
# | `height` | `int` | `500` | no |
# | `background` | `str` | `'white'` | no |
# | `style` | `RenderStyle` | `'ball_and_stick'` | no |
# | `backend` | `BackendName` | `'auto'` | no |
# | `camera` | `Literal['perspective', 'orthographic']` | `'perspective'` | no |
# | `spin` | `bool` | `False` | no |
# | `atom_labels` | `bool` | `False` | no |
# | `atom_indices` | `bool` | `False` | no |
# | `show_hydrogens` | `bool` | `True` | no |
# | `show_bonds` | `bool` | `True` | no |
# | `show_unit_cell` | `bool` | `True` | no |
# | `show_axes` | `bool` | `False` | no |
# | `supercell` | `tuple[int, int, int]` | `(1, 1, 1)` | no |
# | `sphere_scale` | `float` | `0.28` | no |
# | `stick_radius` | `float` | `0.16` | no |
# | `line_width` | `float` | `1.5` | no |
# | `surface_opacity` | `float` | `0.45` | no |
# | `zoom` | `float` | `1.0` | no |
# | `color_by` | `Literal['element', 'unit', 'role', 'chain']` | `'element'` | no |
# | `metadata` | `dict[str, Any]` | `field(default_factory=dict)` | no |

# %%
import inspect

if API is not None:
    try:
        print(inspect.signature(API))
    except (TypeError, ValueError):
        print('This public object has no callable signature.')
    summary = (getattr(API, '__doc__', None) or '').strip()
    print(summary.split('\n\n', 1)[0] if summary else 'No public docstring.')

# %% [markdown]
# ## Minimal public usage
#
# The example below stays on the public API surface.

# %%
if API is not None:
    value = API()
    print(value)

# %% [markdown]
# ## Expected behavior and common failures
#
# - `ValueError('viewer width and height must be positive')`
# - `ValueError('supercell must contain three positive integers')`
# - `ValueError('sphere_scale and stick_radius must be positive')`
# - `ValueError('surface_opacity must lie in [0, 1]')`
# - `ValueError('zoom must be positive')`
#
# For dataset downloads, model training, molecular dynamics, and external engines, first test with a small input and an explicit output directory.
