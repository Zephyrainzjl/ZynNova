# %% [markdown]
# # `zynnova.visualization.visualize_polymer`
#
# Public API notebook for **visualize_polymer**. This page only uses the supported public import path and intentionally omits internal implementation details.
#
# **Purpose:** Display a polymer record, atomistic chain, coarse-grained chain, or trajectory.

# %% [markdown]
# ## Installation
#
# Recommended installation for this API: `pip install 'zynnova[visualization]'`.
#
# Run this notebook from an environment where ZynNova is installed. Expensive downloads, training, visualization, and simulations are disabled by default.

# %%
try:
    from zynnova.visualization import visualize_polymer as API
except ImportError as exc:
    API = None
    print('Optional dependency or installation is missing:', exc)
else:
    print('Imported: zynnova.visualization.visualize_polymer')

# %% [markdown]
# ## Signature
#
# ```python
# visualize_polymer(source: Any, *, backend: str = 'auto', style: str = 'ball_and_stick', resolution: str = 'atomistic', state_id: str | None = None, frame_index: int = 0, trajectory: bool = False, color_by: str = 'unit', width: int = 900, height: int = 560, background: str = 'white', camera: str = 'perspective', atom_labels: bool = False, atom_indices: bool = False, show_hydrogens: bool = True, show_bonds: bool = True, show_unit_cell: bool = True, spin: bool = False, interval: int = 100, loop: str = 'forward', reps: int = 0, initial_frame: int = 0, **kwargs: Any) -> Any
# ```
#
# | Parameter | Type | Default | Required |
# |---|---|---|---|
# | `source` | `Any` | `-` | yes |
# | `backend` | `str` | `'auto'` | no |
# | `style` | `str` | `'ball_and_stick'` | no |
# | `resolution` | `str` | `'atomistic'` | no |
# | `state_id` | `str \| None` | `None` | no |
# | `frame_index` | `int` | `0` | no |
# | `trajectory` | `bool` | `False` | no |
# | `color_by` | `str` | `'unit'` | no |
# | `width` | `int` | `900` | no |
# | `height` | `int` | `560` | no |
# | `background` | `str` | `'white'` | no |
# | `camera` | `str` | `'perspective'` | no |
# | `atom_labels` | `bool` | `False` | no |
# | `atom_indices` | `bool` | `False` | no |
# | `show_hydrogens` | `bool` | `True` | no |
# | `show_bonds` | `bool` | `True` | no |
# | `show_unit_cell` | `bool` | `True` | no |
# | `spin` | `bool` | `False` | no |
# | `interval` | `int` | `100` | no |
# | `loop` | `str` | `'forward'` | no |
# | `reps` | `int` | `0` | no |
# | `initial_frame` | `int` | `0` | no |
# | `**kwargs` | `Any` | `-` | no |

# %%
import inspect

if API is not None:
    try:
        print(inspect.signature(API))
    except (TypeError, ValueError):
        print('This public object has no callable signature.')
    summary = (getattr(API, '__doc__', None) or '').strip()
    print(summary.split('\n\n', 1)[0] if summary else 'No public docstring.')

# %% [markdown]
# ## Minimal public usage
#
# The example below stays on the public API surface.

# %%
RUN_EXAMPLE = False  # Set True after replacing placeholders with your data.

if API is not None and RUN_EXAMPLE:
    result = API(...)  # Signature: visualize_polymer(source: Any, *, backend: str = 'auto', style: str = 'ball_and_stick', resolution: str = 'atomistic', state_id: str | None = None, frame_index: int = 0, trajectory: bool = False, color_by: str = 'unit', width: int = 900, height: int = 560, background: str = 'white', camera: str = 'perspective', atom_labels: bool = False, atom_indices: bool = False, show_hydrogens: bool = True, show_bonds: bool = True, show_unit_cell: bool = True, spin: bool = False, interval: int = 100, loop: str = 'forward', reps: int = 0, initial_frame: int = 0, **kwargs: Any) -> Any
    print(result)

# %% [markdown]
# ## Expected behavior and common failures
#
# - `TypeError('unit-level visualization requires a PolymerRecord')`
# - `ValueError('unit-level polymer visualization currently uses the py3dmol backend')`
#
# For dataset downloads, model training, molecular dynamics, and external engines, first test with a small input and an explicit output directory.
