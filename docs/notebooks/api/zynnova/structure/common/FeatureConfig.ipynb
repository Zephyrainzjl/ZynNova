# %% [markdown]
# # `zynnova.structure.common.FeatureConfig`
#
# Public API notebook for **FeatureConfig**. This page only uses the supported public import path and intentionally omits internal implementation details.
#
# **Purpose:** Controls deterministic atom and edge feature construction.

# %% [markdown]
# ## Installation
#
# Recommended installation for this source tree: `python -m pip install -e .`.
#
# Run this notebook from an environment where ZynNova is installed. Expensive downloads, training, visualization, and simulations are disabled by default.

# %%
try:
    from zynnova.structure.common import FeatureConfig as API
except ImportError as exc:
    API = None
    print('Optional dependency or installation is missing:', exc)
else:
    print('Imported: zynnova.structure.common.FeatureConfig')

# %% [markdown]
# ## Signature
#
# ```python
# FeatureConfig(include_charge: bool = True, include_mass: bool = True, include_radii: bool = True, include_period_group: bool = True, include_electronegativity: bool = True, include_edge_vector: bool = True, include_unit_vector: bool = True, include_periodic_shift: bool = True, normalize_atomic_number: bool = True)
# ```
#
# | Parameter | Type | Default | Required |
# |---|---|---|---|
# | `include_charge` | `bool` | `True` | no |
# | `include_mass` | `bool` | `True` | no |
# | `include_radii` | `bool` | `True` | no |
# | `include_period_group` | `bool` | `True` | no |
# | `include_electronegativity` | `bool` | `True` | no |
# | `include_edge_vector` | `bool` | `True` | no |
# | `include_unit_vector` | `bool` | `True` | no |
# | `include_periodic_shift` | `bool` | `True` | no |
# | `normalize_atomic_number` | `bool` | `True` | no |

# %%
import inspect

if API is not None:
    try:
        print(inspect.signature(API))
    except (TypeError, ValueError):
        print('This public object has no callable signature.')
    summary = (getattr(API, '__doc__', None) or '').strip()
    print(summary.split('\n\n', 1)[0] if summary else 'No public docstring.')

# %% [markdown]
# ## Minimal public usage
#
# The example below stays on the public API surface.

# %%
if API is not None:
    value = API()
    print(value)

# %% [markdown]
# ## Expected behavior and common failures
#
# - Validate shapes, units, optional dependencies, and output paths before production use.
#
# For dataset downloads, model training, molecular dynamics, and external engines, first test with a small input and an explicit output directory.
