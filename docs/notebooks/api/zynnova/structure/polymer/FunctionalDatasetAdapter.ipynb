# %% [markdown]
# # `zynnova.structure.polymer.FunctionalDatasetAdapter`
#
# Public API notebook for **FunctionalDatasetAdapter**. This page only uses the supported public import path and intentionally omits internal implementation details.
#
# **Purpose:** Public dataclass `FunctionalDatasetAdapter`.

# %% [markdown]
# ## Installation
#
# Recommended installation for this API: `pip install 'zynnova[io]'`.
#
# Run this notebook from an environment where ZynNova is installed. Expensive downloads, training, visualization, and simulations are disabled by default.

# %%
try:
    from zynnova.structure.polymer import FunctionalDatasetAdapter as API
except ImportError as exc:
    API = None
    print('Optional dependency or installation is missing:', exc)
else:
    print('Imported: zynnova.structure.polymer.FunctionalDatasetAdapter')

# %% [markdown]
# ## Signature
#
# ```python
# FunctionalDatasetAdapter(name: str, predicate: Callable[[Any], bool], reader: Callable[[Any], Iterable[RawRecord]], converter: Callable[[RawRecord], PolymerRecord])
# ```
#
# | Parameter | Type | Default | Required |
# |---|---|---|---|
# | `name` | `str` | `-` | yes |
# | `predicate` | `Callable[[Any], bool]` | `-` | yes |
# | `reader` | `Callable[[Any], Iterable[RawRecord]]` | `-` | yes |
# | `converter` | `Callable[[RawRecord], PolymerRecord]` | `-` | yes |

# %%
import inspect

if API is not None:
    try:
        print(inspect.signature(API))
    except (TypeError, ValueError):
        print('This public object has no callable signature.')
    summary = (getattr(API, '__doc__', None) or '').strip()
    print(summary.split('\n\n', 1)[0] if summary else 'No public docstring.')

# %% [markdown]
# ## Minimal public usage
#
# The example below stays on the public API surface.

# %%
RUN_EXAMPLE = False  # Set True after supplying the required constructor values.

if API is not None and RUN_EXAMPLE:
    value = API(...)  # Signature: FunctionalDatasetAdapter(name: str, predicate: Callable[[Any], bool], reader: Callable[[Any], Iterable[RawRecord]], converter: Callable[[RawRecord], PolymerRecord])
    print(value)

# %% [markdown]
# ## Expected behavior and common failures
#
# - Validate shapes, units, optional dependencies, and output paths before production use.
#
# For dataset downloads, model training, molecular dynamics, and external engines, first test with a small input and an explicit output directory.
