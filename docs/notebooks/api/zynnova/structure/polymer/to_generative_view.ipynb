# %% [markdown]
# # `zynnova.structure.polymer.to_generative_view`
#
# Public API notebook for **to_generative_view**. This page only uses the supported public import path and intentionally omits internal implementation details.
#
# **Purpose:** Public function `to_generative_view`.

# %% [markdown]
# ## Installation
#
# Recommended installation for this API: `pip install 'zynnova[io]'`.
#
# Run this notebook from an environment where ZynNova is installed. Expensive downloads, training, visualization, and simulations are disabled by default.

# %%
try:
    from zynnova.structure.polymer import to_generative_view as API
except ImportError as exc:
    API = None
    print('Optional dependency or installation is missing:', exc)
else:
    print('Imported: zynnova.structure.polymer.to_generative_view')

# %% [markdown]
# ## Signature
#
# ```python
# to_generative_view(record: PolymerRecord, *, schema: RepresentationSchema, level: Literal['unit', 'atom'] = 'unit', max_nodes: int | None = None, state_id: str | None = None, frame_index: int = 0, include_reconstruction: bool = True) -> GenerativeTensorView
# ```
#
# | Parameter | Type | Default | Required |
# |---|---|---|---|
# | `record` | `PolymerRecord` | `-` | yes |
# | `schema` | `RepresentationSchema` | `-` | yes |
# | `level` | `Literal['unit', 'atom']` | `'unit'` | no |
# | `max_nodes` | `int \| None` | `None` | no |
# | `state_id` | `str \| None` | `None` | no |
# | `frame_index` | `int` | `0` | no |
# | `include_reconstruction` | `bool` | `True` | no |

# %%
import inspect

if API is not None:
    try:
        print(inspect.signature(API))
    except (TypeError, ValueError):
        print('This public object has no callable signature.')
    summary = (getattr(API, '__doc__', None) or '').strip()
    print(summary.split('\n\n', 1)[0] if summary else 'No public docstring.')

# %% [markdown]
# ## Minimal public usage
#
# The example below stays on the public API surface.

# %%
RUN_EXAMPLE = False  # Set True after replacing placeholders with your data.

if API is not None and RUN_EXAMPLE:
    result = API(...)  # Signature: to_generative_view(record: PolymerRecord, *, schema: RepresentationSchema, level: Literal['unit', 'atom'] = 'unit', max_nodes: int | None = None, state_id: str | None = None, frame_index: int = 0, include_reconstruction: bool = True) -> GenerativeTensorView
    print(result)

# %% [markdown]
# ## Expected behavior and common failures
#
# - `ValueError("level must be 'unit' or 'atom'")`
#
# For dataset downloads, model training, molecular dynamics, and external engines, first test with a small input and an explicit output directory.
