# %% [markdown]
# # `zynnova.structure.polymer.PolymerArchitecture`
#
# Public API notebook for **PolymerArchitecture**. This page only uses the supported public import path and intentionally omits internal implementation details.
#
# **Purpose:** Public dataclass `PolymerArchitecture`.

# %% [markdown]
# ## Installation
#
# Recommended installation for this API: `pip install 'zynnova[io]'`.
#
# Run this notebook from an environment where ZynNova is installed. Expensive downloads, training, visualization, and simulations are disabled by default.

# %%
try:
    from zynnova.structure.polymer import PolymerArchitecture as API
except ImportError as exc:
    API = None
    print('Optional dependency or installation is missing:', exc)
else:
    print('Imported: zynnova.structure.polymer.PolymerArchitecture')

# %% [markdown]
# ## Signature
#
# ```python
# PolymerArchitecture(architecture_type: ArchitectureType, nodes: list[ArchitectureNode] = field(default_factory=list), edges: list[ArchitectureEdge] = field(default_factory=list), sequence: list[str] | None = None, head_node: str | None = None, tail_node: str | None = None, metadata: dict[str, Any] = field(default_factory=dict))
# ```
#
# | Parameter | Type | Default | Required |
# |---|---|---|---|
# | `architecture_type` | `ArchitectureType` | `-` | yes |
# | `nodes` | `list[ArchitectureNode]` | `field(default_factory=list)` | no |
# | `edges` | `list[ArchitectureEdge]` | `field(default_factory=list)` | no |
# | `sequence` | `list[str] \| None` | `None` | no |
# | `head_node` | `str \| None` | `None` | no |
# | `tail_node` | `str \| None` | `None` | no |
# | `metadata` | `dict[str, Any]` | `field(default_factory=dict)` | no |

# %%
import inspect

if API is not None:
    try:
        print(inspect.signature(API))
    except (TypeError, ValueError):
        print('This public object has no callable signature.')
    summary = (getattr(API, '__doc__', None) or '').strip()
    print(summary.split('\n\n', 1)[0] if summary else 'No public docstring.')

# %% [markdown]
# ## Minimal public usage
#
# The example below stays on the public API surface.

# %%
RUN_EXAMPLE = False  # Set True after supplying the required constructor values.

if API is not None and RUN_EXAMPLE:
    value = API(...)  # Signature: PolymerArchitecture(architecture_type: ArchitectureType, nodes: list[ArchitectureNode] = field(default_factory=list), edges: list[ArchitectureEdge] = field(default_factory=list), sequence: list[str] | None = None, head_node: str | None = None, tail_node: str | None = None, metadata: dict[str, Any] = field(default_factory=dict))
    print(value)

# %% [markdown]
# ## Expected behavior and common failures
#
# - `ValueError('architecture node ids must be unique')`
# - `ValueError('head_node is unknown')`
# - `ValueError('tail_node is unknown')`
# - `ValueError(f'architecture node references unknown unit: {node.unit_id}')`
# - `ValueError('architecture edge references unknown node')`
# - `ValueError('edge probability must lie in [0, 1]')`
# - `ValueError(f'sequence references unknown units: {sorted(unknown)}')`
#
# For dataset downloads, model training, molecular dynamics, and external engines, first test with a small input and an explicit output directory.
