# %% [markdown]
# # `zynnova.structure.polymer.ProcessHistory`
#
# Public API notebook for **ProcessHistory**. This page only uses the supported public import path and intentionally omits internal implementation details.
#
# **Purpose:** Public dataclass `ProcessHistory`.

# %% [markdown]
# ## Installation
#
# Recommended installation for this API: `pip install 'zynnova[io]'`.
#
# Run this notebook from an environment where ZynNova is installed. Expensive downloads, training, visualization, and simulations are disabled by default.

# %%
try:
    from zynnova.structure.polymer import ProcessHistory as API
except ImportError as exc:
    API = None
    print('Optional dependency or installation is missing:', exc)
else:
    print('Imported: zynnova.structure.polymer.ProcessHistory')

# %% [markdown]
# ## Signature
#
# ```python
# ProcessHistory(steps: list[ProcessStep] = field(default_factory=list), dependencies: list[tuple[str, str]] = field(default_factory=list))
# ```
#
# | Parameter | Type | Default | Required |
# |---|---|---|---|
# | `steps` | `list[ProcessStep]` | `field(default_factory=list)` | no |
# | `dependencies` | `list[tuple[str, str]]` | `field(default_factory=list)` | no |

# %%
import inspect

if API is not None:
    try:
        print(inspect.signature(API))
    except (TypeError, ValueError):
        print('This public object has no callable signature.')
    summary = (getattr(API, '__doc__', None) or '').strip()
    print(summary.split('\n\n', 1)[0] if summary else 'No public docstring.')

# %% [markdown]
# ## Minimal public usage
#
# The example below stays on the public API surface.

# %%
if API is not None:
    value = API()
    print(value)

# %% [markdown]
# ## Expected behavior and common failures
#
# - `ValueError('process step ids must be unique')`
# - `ValueError('process dependency references unknown step')`
#
# For dataset downloads, model training, molecular dynamics, and external engines, first test with a small input and an explicit output directory.
