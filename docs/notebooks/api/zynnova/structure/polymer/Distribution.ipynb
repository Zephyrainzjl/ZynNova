# %% [markdown]
# # `zynnova.structure.polymer.Distribution`
#
# Public API notebook for **Distribution**. This page only uses the supported public import path and intentionally omits internal implementation details.
#
# **Purpose:** Public dataclass `Distribution`.

# %% [markdown]
# ## Installation
#
# Recommended installation for this API: `pip install 'zynnova[io]'`.
#
# Run this notebook from an environment where ZynNova is installed. Expensive downloads, training, visualization, and simulations are disabled by default.

# %%
try:
    from zynnova.structure.polymer import Distribution as API
except ImportError as exc:
    API = None
    print('Optional dependency or installation is missing:', exc)
else:
    print('Imported: zynnova.structure.polymer.Distribution')

# %% [markdown]
# ## Signature
#
# ```python
# Distribution(kind: DistributionKind, parameters: dict[str, float] = field(default_factory=dict), samples: np.ndarray | None = None, bin_edges: np.ndarray | None = None, probabilities: np.ndarray | None = None, unit: str | None = None, uncertainty: dict[str, Any] = field(default_factory=dict), metadata: dict[str, Any] = field(default_factory=dict))
# ```
#
# | Parameter | Type | Default | Required |
# |---|---|---|---|
# | `kind` | `DistributionKind` | `-` | yes |
# | `parameters` | `dict[str, float]` | `field(default_factory=dict)` | no |
# | `samples` | `np.ndarray \| None` | `None` | no |
# | `bin_edges` | `np.ndarray \| None` | `None` | no |
# | `probabilities` | `np.ndarray \| None` | `None` | no |
# | `unit` | `str \| None` | `None` | no |
# | `uncertainty` | `dict[str, Any]` | `field(default_factory=dict)` | no |
# | `metadata` | `dict[str, Any]` | `field(default_factory=dict)` | no |

# %%
import inspect

if API is not None:
    try:
        print(inspect.signature(API))
    except (TypeError, ValueError):
        print('This public object has no callable signature.')
    summary = (getattr(API, '__doc__', None) or '').strip()
    print(summary.split('\n\n', 1)[0] if summary else 'No public docstring.')

# %% [markdown]
# ## Minimal public usage
#
# The example below stays on the public API surface.

# %%
RUN_EXAMPLE = False  # Set True after supplying the required constructor values.

if API is not None and RUN_EXAMPLE:
    value = API(...)  # Signature: Distribution(kind: DistributionKind, parameters: dict[str, float] = field(default_factory=dict), samples: np.ndarray | None = None, bin_edges: np.ndarray | None = None, probabilities: np.ndarray | None = None, unit: str | None = None, uncertainty: dict[str, Any] = field(default_factory=dict), metadata: dict[str, Any] = field(default_factory=dict))
    print(value)

# %% [markdown]
# ## Expected behavior and common failures
#
# - `ValueError('distribution samples must be one-dimensional')`
# - `ValueError('histogram requires both bin_edges and probabilities')`
# - `ValueError('len(bin_edges) must equal len(probabilities) + 1')`
# - `ValueError('histogram probabilities cannot be negative')`
# - `ValueError('histogram probability sum must be positive')`
#
# For dataset downloads, model training, molecular dynamics, and external engines, first test with a small input and an explicit output directory.
