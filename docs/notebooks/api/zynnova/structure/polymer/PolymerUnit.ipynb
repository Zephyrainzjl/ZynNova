# %% [markdown]
# # `zynnova.structure.polymer.PolymerUnit`
#
# Public API notebook for **PolymerUnit**. This page only uses the supported public import path and intentionally omits internal implementation details.
#
# **Purpose:** Public dataclass `PolymerUnit`.

# %% [markdown]
# ## Installation
#
# Recommended installation for this API: `pip install 'zynnova[io]'`.
#
# Run this notebook from an environment where ZynNova is installed. Expensive downloads, training, visualization, and simulations are disabled by default.

# %%
try:
    from zynnova.structure.polymer import PolymerUnit as API
except ImportError as exc:
    API = None
    print('Optional dependency or installation is missing:', exc)
else:
    print('Imported: zynnova.structure.polymer.PolymerUnit')

# %% [markdown]
# ## Signature
#
# ```python
# PolymerUnit(id: str, role: UnitRole, graph: MolecularGraph, name: str | None = None, aliases: list[str] = field(default_factory=list), descriptors: dict[str, float] = field(default_factory=dict), metadata: dict[str, Any] = field(default_factory=dict))
# ```
#
# | Parameter | Type | Default | Required |
# |---|---|---|---|
# | `id` | `str` | `-` | yes |
# | `role` | `UnitRole` | `-` | yes |
# | `graph` | `MolecularGraph` | `-` | yes |
# | `name` | `str \| None` | `None` | no |
# | `aliases` | `list[str]` | `field(default_factory=list)` | no |
# | `descriptors` | `dict[str, float]` | `field(default_factory=dict)` | no |
# | `metadata` | `dict[str, Any]` | `field(default_factory=dict)` | no |

# %%
import inspect

if API is not None:
    try:
        print(inspect.signature(API))
    except (TypeError, ValueError):
        print('This public object has no callable signature.')
    summary = (getattr(API, '__doc__', None) or '').strip()
    print(summary.split('\n\n', 1)[0] if summary else 'No public docstring.')

# %% [markdown]
# ## Minimal public usage
#
# The example below stays on the public API surface.

# %%
RUN_EXAMPLE = False  # Set True after supplying the required constructor values.

if API is not None and RUN_EXAMPLE:
    value = API(...)  # Signature: PolymerUnit(id: str, role: UnitRole, graph: MolecularGraph, name: str | None = None, aliases: list[str] = field(default_factory=list), descriptors: dict[str, float] = field(default_factory=dict), metadata: dict[str, Any] = field(default_factory=dict))
    print(value)

# %% [markdown]
# ## Expected behavior and common failures
#
# - `ValueError('polymer unit id cannot be empty')`
#
# For dataset downloads, model training, molecular dynamics, and external engines, first test with a small input and an explicit output directory.
