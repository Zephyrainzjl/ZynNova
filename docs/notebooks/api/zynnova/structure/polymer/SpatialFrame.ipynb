# %% [markdown]
# # `zynnova.structure.polymer.SpatialFrame`
#
# Public API notebook for **SpatialFrame**. This page only uses the supported public import path and intentionally omits internal implementation details.
#
# **Purpose:** Public dataclass `SpatialFrame`.

# %% [markdown]
# ## Installation
#
# Recommended installation for this API: `pip install 'zynnova[io]'`.
#
# Run this notebook from an environment where ZynNova is installed. Expensive downloads, training, visualization, and simulations are disabled by default.

# %%
try:
    from zynnova.structure.polymer import SpatialFrame as API
except ImportError as exc:
    API = None
    print('Optional dependency or installation is missing:', exc)
else:
    print('Imported: zynnova.structure.polymer.SpatialFrame')

# %% [markdown]
# ## Signature
#
# ```python
# SpatialFrame(resolution: Resolution, node_ids: list[str], coordinates: np.ndarray, box: PeriodicBox | None = None, velocities: np.ndarray | None = None, forces: np.ndarray | None = None, orientations: np.ndarray | None = None, spatial_edge_index: np.ndarray | None = None, periodic_edge_shift: np.ndarray | None = None, phase_labels: np.ndarray | None = None, time: float | None = None, units: dict[str, str] = field(default_factory=lambda: {'length': 'angstrom'}), metadata: dict[str, Any] = field(default_factory=dict))
# ```
#
# | Parameter | Type | Default | Required |
# |---|---|---|---|
# | `resolution` | `Resolution` | `-` | yes |
# | `node_ids` | `list[str]` | `-` | yes |
# | `coordinates` | `np.ndarray` | `-` | yes |
# | `box` | `PeriodicBox \| None` | `None` | no |
# | `velocities` | `np.ndarray \| None` | `None` | no |
# | `forces` | `np.ndarray \| None` | `None` | no |
# | `orientations` | `np.ndarray \| None` | `None` | no |
# | `spatial_edge_index` | `np.ndarray \| None` | `None` | no |
# | `periodic_edge_shift` | `np.ndarray \| None` | `None` | no |
# | `phase_labels` | `np.ndarray \| None` | `None` | no |
# | `time` | `float \| None` | `None` | no |
# | `units` | `dict[str, str]` | `field(default_factory=lambda: {'length': 'angstrom'})` | no |
# | `metadata` | `dict[str, Any]` | `field(default_factory=dict)` | no |

# %%
import inspect

if API is not None:
    try:
        print(inspect.signature(API))
    except (TypeError, ValueError):
        print('This public object has no callable signature.')
    summary = (getattr(API, '__doc__', None) or '').strip()
    print(summary.split('\n\n', 1)[0] if summary else 'No public docstring.')

# %% [markdown]
# ## Minimal public usage
#
# The example below stays on the public API surface.

# %%
RUN_EXAMPLE = False  # Set True after supplying the required constructor values.

if API is not None and RUN_EXAMPLE:
    value = API(...)  # Signature: SpatialFrame(resolution: Resolution, node_ids: list[str], coordinates: np.ndarray, box: PeriodicBox | None = None, velocities: np.ndarray | None = None, forces: np.ndarray | None = None, orientations: np.ndarray | None = None, spatial_edge_index: np.ndarray | None = None, periodic_edge_shift: np.ndarray | None = None, phase_labels: np.ndarray | None = None, time: float | None = None, units: dict[str, str] = field(default_factory=lambda: {'length': 'angstrom'}), metadata: dict[str, Any] = field(default_factory=dict))
    print(value)

# %% [markdown]
# ## Expected behavior and common failures
#
# - `ValueError(f'coordinates must have shape ({n}, 3)')`
# - `ValueError('orientations must be quaternions [N,4] or matrices [N,3,3]')`
# - `ValueError('spatial_edge_index must have shape [2, E]')`
# - `ValueError(f'{name} must have shape ({n}, 3)')`
# - `ValueError('periodic_edge_shift must have shape [E, 3]')`
#
# For dataset downloads, model training, molecular dynamics, and external engines, first test with a small input and an explicit output directory.
