# %% [markdown]
# # `zynnova.structure.polymer.MultiScaleView`
#
# Public API notebook for **MultiScaleView**. This page only uses the supported public import path and intentionally omits internal implementation details.
#
# **Purpose:** Public dataclass `MultiScaleView`.

# %% [markdown]
# ## Installation
#
# Recommended installation for this API: `pip install 'zynnova[io]'`.
#
# Run this notebook from an environment where ZynNova is installed. Expensive downloads, training, visualization, and simulations are disabled by default.

# %%
try:
    from zynnova.structure.polymer import MultiScaleView as API
except ImportError as exc:
    API = None
    print('Optional dependency or installation is missing:', exc)
else:
    print('Imported: zynnova.structure.polymer.MultiScaleView')

# %% [markdown]
# ## Signature
#
# ```python
# MultiScaleView(node_features: dict[str, np.ndarray], node_ids: dict[str, list[str]], relations: list[RelationTable], local_unit_graphs: ChemicalStructureView, graph_features: np.ndarray, graph_feature_names: list[str], spatial: dict[str, Any] = field(default_factory=dict), targets: dict[str, np.ndarray] = field(default_factory=dict), metadata: dict[str, Any] = field(default_factory=dict), record_payload: dict[str, Any] | None = None)
# ```
#
# | Parameter | Type | Default | Required |
# |---|---|---|---|
# | `node_features` | `dict[str, np.ndarray]` | `-` | yes |
# | `node_ids` | `dict[str, list[str]]` | `-` | yes |
# | `relations` | `list[RelationTable]` | `-` | yes |
# | `local_unit_graphs` | `ChemicalStructureView` | `-` | yes |
# | `graph_features` | `np.ndarray` | `-` | yes |
# | `graph_feature_names` | `list[str]` | `-` | yes |
# | `spatial` | `dict[str, Any]` | `field(default_factory=dict)` | no |
# | `targets` | `dict[str, np.ndarray]` | `field(default_factory=dict)` | no |
# | `metadata` | `dict[str, Any]` | `field(default_factory=dict)` | no |
# | `record_payload` | `dict[str, Any] \| None` | `None` | no |

# %%
import inspect

if API is not None:
    try:
        print(inspect.signature(API))
    except (TypeError, ValueError):
        print('This public object has no callable signature.')
    summary = (getattr(API, '__doc__', None) or '').strip()
    print(summary.split('\n\n', 1)[0] if summary else 'No public docstring.')

# %% [markdown]
# ## Minimal public usage
#
# The example below stays on the public API surface.

# %%
RUN_EXAMPLE = False  # Set True after supplying the required constructor values.

if API is not None and RUN_EXAMPLE:
    value = API(...)  # Signature: MultiScaleView(node_features: dict[str, np.ndarray], node_ids: dict[str, list[str]], relations: list[RelationTable], local_unit_graphs: ChemicalStructureView, graph_features: np.ndarray, graph_feature_names: list[str], spatial: dict[str, Any] = field(default_factory=dict), targets: dict[str, np.ndarray] = field(default_factory=dict), metadata: dict[str, Any] = field(default_factory=dict), record_payload: dict[str, Any] | None = None)
    print(value)

# %% [markdown]
# ## Expected behavior and common failures
#
# - Validate shapes, units, optional dependencies, and output paths before production use.
#
# For dataset downloads, model training, molecular dynamics, and external engines, first test with a small input and an explicit output directory.
