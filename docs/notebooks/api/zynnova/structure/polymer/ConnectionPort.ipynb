# %% [markdown]
# # `zynnova.structure.polymer.ConnectionPort`
#
# Public API notebook for **ConnectionPort**. This page only uses the supported public import path and intentionally omits internal implementation details.
#
# **Purpose:** Public dataclass `ConnectionPort`.

# %% [markdown]
# ## Installation
#
# Recommended installation for this API: `pip install 'zynnova[io]'`.
#
# Run this notebook from an environment where ZynNova is installed. Expensive downloads, training, visualization, and simulations are disabled by default.

# %%
try:
    from zynnova.structure.polymer import ConnectionPort as API
except ImportError as exc:
    API = None
    print('Optional dependency or installation is missing:', exc)
else:
    print('Imported: zynnova.structure.polymer.ConnectionPort')

# %% [markdown]
# ## Signature
#
# ```python
# ConnectionPort(id: str, atom_index: int, port_type: str = 'generic', direction: str | None = None, valence: int = 1, leaving_atom_indices: list[int] = field(default_factory=list), allowed_partner_types: set[str] = field(default_factory=set), features: dict[str, Any] = field(default_factory=dict))
# ```
#
# | Parameter | Type | Default | Required |
# |---|---|---|---|
# | `id` | `str` | `-` | yes |
# | `atom_index` | `int` | `-` | yes |
# | `port_type` | `str` | `'generic'` | no |
# | `direction` | `str \| None` | `None` | no |
# | `valence` | `int` | `1` | no |
# | `leaving_atom_indices` | `list[int]` | `field(default_factory=list)` | no |
# | `allowed_partner_types` | `set[str]` | `field(default_factory=set)` | no |
# | `features` | `dict[str, Any]` | `field(default_factory=dict)` | no |

# %%
import inspect

if API is not None:
    try:
        print(inspect.signature(API))
    except (TypeError, ValueError):
        print('This public object has no callable signature.')
    summary = (getattr(API, '__doc__', None) or '').strip()
    print(summary.split('\n\n', 1)[0] if summary else 'No public docstring.')

# %% [markdown]
# ## Minimal public usage
#
# The example below stays on the public API surface.

# %%
RUN_EXAMPLE = False  # Set True after supplying the required constructor values.

if API is not None and RUN_EXAMPLE:
    value = API(...)  # Signature: ConnectionPort(id: str, atom_index: int, port_type: str = 'generic', direction: str | None = None, valence: int = 1, leaving_atom_indices: list[int] = field(default_factory=list), allowed_partner_types: set[str] = field(default_factory=set), features: dict[str, Any] = field(default_factory=dict))
    print(value)

# %% [markdown]
# ## Expected behavior and common failures
#
# - `ValueError('port id cannot be empty')`
# - `IndexError('port atom index out of range')`
# - `ValueError('port valence must be >= 1')`
# - `IndexError('leaving atom index out of range')`
#
# For dataset downloads, model training, molecular dynamics, and external engines, first test with a small input and an explicit output directory.
