# %% [markdown]
# # `zynnova.structure.polymer.stru2graph`
#
# Public API notebook for **stru2graph**. This page only uses the supported public import path and intentionally omits internal implementation details.
#
# **Purpose:** Convert a polymer structure to an atom graph or a polymer ML view.

# %% [markdown]
# ## Installation
#
# Recommended installation for this API: `pip install 'zynnova[io]'`.
#
# Run this notebook from an environment where ZynNova is installed. Expensive downloads, training, visualization, and simulations are disabled by default.

# %%
try:
    from zynnova.structure.polymer import stru2graph as API
except ImportError as exc:
    API = None
    print('Optional dependency or installation is missing:', exc)
else:
    print('Imported: zynnova.structure.polymer.stru2graph')

# %% [markdown]
# ## Signature
#
# ```python
# stru2graph(structure: Any, *, representation: Literal['atom', 'single_chain', 'multiscale', 'generative', 'generative_atom'] = 'atom', record: PolymerRecord | None = None, schema: RepresentationSchema | None = None, state_id: str | None = None, frame_index: int = 0, format: str | None = None, index: int | str = -1, backend: BackendName = 'auto', neighbor_mode: str = 'radius', cutoff: float = 3.0, radius_scale: float = 1.2, max_neighbors: int | None = None, directed: bool = True, self_edges: bool = False, use_explicit_bonds: bool = True, feature_config: FeatureConfig | None = None, tolerance: float = 1e-08, as_pyg: bool = False, include_reconstruction: bool = True, **record_kwargs: Any) -> GraphData | Any
# ```
#
# | Parameter | Type | Default | Required |
# |---|---|---|---|
# | `structure` | `Any` | `-` | yes |
# | `representation` | `Literal['atom', 'single_chain', 'multiscale', 'generative', 'generative_atom']` | `'atom'` | no |
# | `record` | `PolymerRecord \| None` | `None` | no |
# | `schema` | `RepresentationSchema \| None` | `None` | no |
# | `state_id` | `str \| None` | `None` | no |
# | `frame_index` | `int` | `0` | no |
# | `format` | `str \| None` | `None` | no |
# | `index` | `int \| str` | `-1` | no |
# | `backend` | `BackendName` | `'auto'` | no |
# | `neighbor_mode` | `str` | `'radius'` | no |
# | `cutoff` | `float` | `3.0` | no |
# | `radius_scale` | `float` | `1.2` | no |
# | `max_neighbors` | `int \| None` | `None` | no |
# | `directed` | `bool` | `True` | no |
# | `self_edges` | `bool` | `False` | no |
# | `use_explicit_bonds` | `bool` | `True` | no |
# | `feature_config` | `FeatureConfig \| None` | `None` | no |
# | `tolerance` | `float` | `1e-08` | no |
# | `as_pyg` | `bool` | `False` | no |
# | `include_reconstruction` | `bool` | `True` | no |
# | `**record_kwargs` | `Any` | `-` | no |

# %%
import inspect

if API is not None:
    try:
        print(inspect.signature(API))
    except (TypeError, ValueError):
        print('This public object has no callable signature.')
    summary = (getattr(API, '__doc__', None) or '').strip()
    print(summary.split('\n\n', 1)[0] if summary else 'No public docstring.')

# %% [markdown]
# ## Minimal public usage
#
# The example below stays on the public API surface.

# %%
RUN_EXAMPLE = False  # Set True after replacing placeholders with your data.

if API is not None and RUN_EXAMPLE:
    result = API(...)  # Signature: stru2graph(structure: Any, *, representation: Literal['atom', 'single_chain', 'multiscale', 'generative', 'generative_atom'] = 'atom', record: PolymerRecord | None = None, schema: RepresentationSchema | None = None, state_id: str | None = None, frame_index: int = 0, format: str | None = None, index: int | str = -1, backend: BackendName = 'auto', neighbor_mode: str = 'radius', cutoff: float = 3.0, radius_scale: float = 1.2, max_neighbors: int | None = None, directed: bool = True, self_edges: bool = False, use_explicit_bonds: bool = True, feature_config: FeatureConfig | None = None, tolerance: float = 1e-08, as_pyg: bool = False, include_reconstruction: bool = True, **record_kwargs: Any) -> GraphData | Any
    print(result)

# %% [markdown]
# ## Expected behavior and common failures
#
# - `ValueError(f'unsupported polymer representation: {representation}')`
# - `ValueError('schema is required for generative representations')`
#
# For dataset downloads, model training, molecular dynamics, and external engines, first test with a small input and an explicit output directory.
