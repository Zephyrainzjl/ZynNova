# %% [markdown]
# # `zynnova.structure.polymer.PolymerRecord`
#
# Public API notebook for **PolymerRecord**. This page only uses the supported public import path and intentionally omits internal implementation details.
#
# **Purpose:** Public dataclass `PolymerRecord`.

# %% [markdown]
# ## Installation
#
# Recommended installation for this API: `pip install 'zynnova[io]'`.
#
# Run this notebook from an environment where ZynNova is installed. Expensive downloads, training, visualization, and simulations are disabled by default.

# %%
try:
    from zynnova.structure.polymer import PolymerRecord as API
except ImportError as exc:
    API = None
    print('Optional dependency or installation is missing:', exc)
else:
    print('Imported: zynnova.structure.polymer.PolymerRecord')

# %% [markdown]
# ## Signature
#
# ```python
# PolymerRecord(id: str, units: dict[str, PolymerUnit], architecture: PolymerArchitecture, ensemble: EnsembleStatistics = field(default_factory=EnsembleStatistics), spatial_states: list[SpatialState] = field(default_factory=list), properties: dict[str, PropertyValue] = field(default_factory=dict), process_history: ProcessHistory = field(default_factory=ProcessHistory), provenance: Provenance = field(default_factory=Provenance), tags: set[str] = field(default_factory=set), metadata: dict[str, Any] = field(default_factory=dict), schema_version: str = '0.1.0')
# ```
#
# | Parameter | Type | Default | Required |
# |---|---|---|---|
# | `id` | `str` | `-` | yes |
# | `units` | `dict[str, PolymerUnit]` | `-` | yes |
# | `architecture` | `PolymerArchitecture` | `-` | yes |
# | `ensemble` | `EnsembleStatistics` | `field(default_factory=EnsembleStatistics)` | no |
# | `spatial_states` | `list[SpatialState]` | `field(default_factory=list)` | no |
# | `properties` | `dict[str, PropertyValue]` | `field(default_factory=dict)` | no |
# | `process_history` | `ProcessHistory` | `field(default_factory=ProcessHistory)` | no |
# | `provenance` | `Provenance` | `field(default_factory=Provenance)` | no |
# | `tags` | `set[str]` | `field(default_factory=set)` | no |
# | `metadata` | `dict[str, Any]` | `field(default_factory=dict)` | no |
# | `schema_version` | `str` | `'0.1.0'` | no |

# %%
import inspect

if API is not None:
    try:
        print(inspect.signature(API))
    except (TypeError, ValueError):
        print('This public object has no callable signature.')
    summary = (getattr(API, '__doc__', None) or '').strip()
    print(summary.split('\n\n', 1)[0] if summary else 'No public docstring.')

# %% [markdown]
# ## Minimal public usage
#
# The example below stays on the public API surface.

# %%
RUN_EXAMPLE = False  # Set True after supplying the required constructor values.

if API is not None and RUN_EXAMPLE:
    value = API(...)  # Signature: PolymerRecord(id: str, units: dict[str, PolymerUnit], architecture: PolymerArchitecture, ensemble: EnsembleStatistics = field(default_factory=EnsembleStatistics), spatial_states: list[SpatialState] = field(default_factory=list), properties: dict[str, PropertyValue] = field(default_factory=dict), process_history: ProcessHistory = field(default_factory=ProcessHistory), provenance: Provenance = field(default_factory=Provenance), tags: set[str] = field(default_factory=set), metadata: dict[str, Any] = field(default_factory=dict), schema_version: str = '0.1.0')
    print(value)

# %% [markdown]
# ## Expected behavior and common failures
#
# - `KeyError(f'unknown spatial state: {state_id}')`
# - `ValueError('polymer record id cannot be empty')`
# - `ValueError('polymer record must contain at least one unit')`
# - `ValueError(f'unit dictionary key {key!r} differs from unit.id {unit.id!r}')`
# - `ValueError(f'duplicate spatial state id: {state.id}')`
#
# For dataset downloads, model training, molecular dynamics, and external engines, first test with a small input and an explicit output directory.
