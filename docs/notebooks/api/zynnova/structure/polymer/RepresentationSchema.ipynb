# %% [markdown]
# # `zynnova.structure.polymer.RepresentationSchema`
#
# Public API notebook for **RepresentationSchema**. This page only uses the supported public import path and intentionally omits internal implementation details.
#
# **Purpose:** Dataset-level tensor contract shared by all polymer training views.

# %% [markdown]
# ## Installation
#
# Recommended installation for this API: `pip install 'zynnova[io]'`.
#
# Run this notebook from an environment where ZynNova is installed. Expensive downloads, training, visualization, and simulations are disabled by default.

# %%
try:
    from zynnova.structure.polymer import RepresentationSchema as API
except ImportError as exc:
    API = None
    print('Optional dependency or installation is missing:', exc)
else:
    print('Imported: zynnova.structure.polymer.RepresentationSchema')

# %% [markdown]
# ## Signature
#
# ```python
# RepresentationSchema(unit_vocabulary: dict[str, int], edge_vocabulary: dict[str, int], max_nodes: int, max_tokens: int = 512, atom_vocabulary: dict[str, int] = field(default_factory=lambda: {'[PAD]': 0, '[UNK]': 1}), bond_vocabulary: dict[str, int] = field(default_factory=lambda: {'none': 0, 'single': 1, 'aromatic': 2, 'double': 3, 'triple': 4, 'other': 5}), max_atoms: int | None = None, property_names: list[str] = field(default_factory=list), continuous_feature_names: list[str] = field(default_factory=lambda: ['log_dp', 'log_mn', 'log_dispersity_minus_one', 'crosslink_density_log1p', 'tacticity_logit']), schema_id: str = 'default', PAD_UNIT: str = '[PAD]', UNK_UNIT: str = '[UNK]', PAD_ATOM: str = '[PAD]', UNK_ATOM: str = '[UNK]', NO_EDGE: str = 'none')
# ```
#
# | Parameter | Type | Default | Required |
# |---|---|---|---|
# | `unit_vocabulary` | `dict[str, int]` | `-` | yes |
# | `edge_vocabulary` | `dict[str, int]` | `-` | yes |
# | `max_nodes` | `int` | `-` | yes |
# | `max_tokens` | `int` | `512` | no |
# | `atom_vocabulary` | `dict[str, int]` | `field(default_factory=lambda: {'[PAD]': 0, '[UNK]': 1})` | no |
# | `bond_vocabulary` | `dict[str, int]` | `field(default_factory=lambda: {'none': 0, 'single': 1, 'aromatic': 2, 'double': 3, 'triple': 4, 'other': 5})` | no |
# | `max_atoms` | `int \| None` | `None` | no |
# | `property_names` | `list[str]` | `field(default_factory=list)` | no |
# | `continuous_feature_names` | `list[str]` | `field(default_factory=lambda: ['log_dp', 'log_mn', 'log_dispersity_minus_one', 'crosslink_density_log1p', 'tacticity_logit'])` | no |
# | `schema_id` | `str` | `'default'` | no |
# | `PAD_UNIT` | `str` | `'[PAD]'` | no |
# | `UNK_UNIT` | `str` | `'[UNK]'` | no |
# | `PAD_ATOM` | `str` | `'[PAD]'` | no |
# | `UNK_ATOM` | `str` | `'[UNK]'` | no |
# | `NO_EDGE` | `str` | `'none'` | no |

# %%
import inspect

if API is not None:
    try:
        print(inspect.signature(API))
    except (TypeError, ValueError):
        print('This public object has no callable signature.')
    summary = (getattr(API, '__doc__', None) or '').strip()
    print(summary.split('\n\n', 1)[0] if summary else 'No public docstring.')

# %% [markdown]
# ## Minimal public usage
#
# The example below stays on the public API surface.

# %%
RUN_EXAMPLE = False  # Set True after supplying the required constructor values.

if API is not None and RUN_EXAMPLE:
    value = API(...)  # Signature: RepresentationSchema(unit_vocabulary: dict[str, int], edge_vocabulary: dict[str, int], max_nodes: int, max_tokens: int = 512, atom_vocabulary: dict[str, int] = field(default_factory=lambda: {'[PAD]': 0, '[UNK]': 1}), bond_vocabulary: dict[str, int] = field(default_factory=lambda: {'none': 0, 'single': 1, 'aromatic': 2, 'double': 3, 'triple': 4, 'other': 5}), max_atoms: int | None = None, property_names: list[str] = field(default_factory=list), continuous_feature_names: list[str] = field(default_factory=lambda: ['log_dp', 'log_mn', 'log_dispersity_minus_one', 'crosslink_density_log1p', 'tacticity_logit']), schema_id: str = 'default', PAD_UNIT: str = '[PAD]', UNK_UNIT: str = '[UNK]', PAD_ATOM: str = '[PAD]', UNK_ATOM: str = '[UNK]', NO_EDGE: str = 'none')
    print(value)

# %% [markdown]
# ## Expected behavior and common failures
#
# - `ValueError('unit_vocabulary must contain [PAD]')`
# - `ValueError('unit_vocabulary must contain [UNK]')`
# - `ValueError("edge_vocabulary must contain 'none'")`
# - `ValueError('atom_vocabulary must contain [PAD]')`
# - `ValueError('atom_vocabulary must contain [UNK]')`
# - `ValueError("bond_vocabulary must contain 'none'")`
# - `ValueError('max_nodes must be positive')`
# - `ValueError('max_atoms must be positive')`
# - `ValueError('cannot fit schema from an empty record collection')`
#
# For dataset downloads, model training, molecular dynamics, and external engines, first test with a small input and an explicit output directory.
