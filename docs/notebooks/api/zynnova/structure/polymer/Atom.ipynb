# %% [markdown]
# # `zynnova.structure.polymer.Atom`
#
# Public API notebook for **Atom**. This page only uses the supported public import path and intentionally omits internal implementation details.
#
# **Purpose:** Public dataclass `Atom`.

# %% [markdown]
# ## Installation
#
# Recommended installation for this API: `pip install 'zynnova[io]'`.
#
# Run this notebook from an environment where ZynNova is installed. Expensive downloads, training, visualization, and simulations are disabled by default.

# %%
try:
    from zynnova.structure.polymer import Atom as API
except ImportError as exc:
    API = None
    print('Optional dependency or installation is missing:', exc)
else:
    print('Imported: zynnova.structure.polymer.Atom')

# %% [markdown]
# ## Signature
#
# ```python
# Atom(atomic_number: int, formal_charge: int = 0, isotope: int | None = None, aromatic: bool = False, chirality: str | None = None, mass: float | None = None, partial_charge: float | None = None, name: str | None = None, features: dict[str, Any] = field(default_factory=dict))
# ```
#
# | Parameter | Type | Default | Required |
# |---|---|---|---|
# | `atomic_number` | `int` | `-` | yes |
# | `formal_charge` | `int` | `0` | no |
# | `isotope` | `int \| None` | `None` | no |
# | `aromatic` | `bool` | `False` | no |
# | `chirality` | `str \| None` | `None` | no |
# | `mass` | `float \| None` | `None` | no |
# | `partial_charge` | `float \| None` | `None` | no |
# | `name` | `str \| None` | `None` | no |
# | `features` | `dict[str, Any]` | `field(default_factory=dict)` | no |

# %%
import inspect

if API is not None:
    try:
        print(inspect.signature(API))
    except (TypeError, ValueError):
        print('This public object has no callable signature.')
    summary = (getattr(API, '__doc__', None) or '').strip()
    print(summary.split('\n\n', 1)[0] if summary else 'No public docstring.')

# %% [markdown]
# ## Minimal public usage
#
# The example below stays on the public API surface.

# %%
RUN_EXAMPLE = False  # Set True after supplying the required constructor values.

if API is not None and RUN_EXAMPLE:
    value = API(...)  # Signature: Atom(atomic_number: int, formal_charge: int = 0, isotope: int | None = None, aromatic: bool = False, chirality: str | None = None, mass: float | None = None, partial_charge: float | None = None, name: str | None = None, features: dict[str, Any] = field(default_factory=dict))
    print(value)

# %% [markdown]
# ## Expected behavior and common failures
#
# - `ValueError('atomic_number must be positive')`
#
# For dataset downloads, model training, molecular dynamics, and external engines, first test with a small input and an explicit output directory.
