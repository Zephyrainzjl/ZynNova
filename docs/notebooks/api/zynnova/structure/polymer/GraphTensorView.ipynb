# %% [markdown]
# # `zynnova.structure.polymer.GraphTensorView`
#
# Public API notebook for **GraphTensorView**. This page only uses the supported public import path and intentionally omits internal implementation details.
#
# **Purpose:** Backend-neutral sparse graph training view.

# %% [markdown]
# ## Installation
#
# Recommended installation for this API: `pip install 'zynnova[io]'`.
#
# Run this notebook from an environment where ZynNova is installed. Expensive downloads, training, visualization, and simulations are disabled by default.

# %%
try:
    from zynnova.structure.polymer import GraphTensorView as API
except ImportError as exc:
    API = None
    print('Optional dependency or installation is missing:', exc)
else:
    print('Imported: zynnova.structure.polymer.GraphTensorView')

# %% [markdown]
# ## Signature
#
# ```python
# GraphTensorView(node_features: np.ndarray, edge_index: np.ndarray, edge_features: np.ndarray | None = None, positions: np.ndarray | None = None, node_ids: list[str] = field(default_factory=list), node_type_ids: np.ndarray | None = None, edge_type_ids: np.ndarray | None = None, graph_features: np.ndarray | None = None, targets: dict[str, np.ndarray] = field(default_factory=dict), masks: dict[str, np.ndarray] = field(default_factory=dict), metadata: dict[str, Any] = field(default_factory=dict), record_payload: dict[str, Any] | None = None)
# ```
#
# | Parameter | Type | Default | Required |
# |---|---|---|---|
# | `node_features` | `np.ndarray` | `-` | yes |
# | `edge_index` | `np.ndarray` | `-` | yes |
# | `edge_features` | `np.ndarray \| None` | `None` | no |
# | `positions` | `np.ndarray \| None` | `None` | no |
# | `node_ids` | `list[str]` | `field(default_factory=list)` | no |
# | `node_type_ids` | `np.ndarray \| None` | `None` | no |
# | `edge_type_ids` | `np.ndarray \| None` | `None` | no |
# | `graph_features` | `np.ndarray \| None` | `None` | no |
# | `targets` | `dict[str, np.ndarray]` | `field(default_factory=dict)` | no |
# | `masks` | `dict[str, np.ndarray]` | `field(default_factory=dict)` | no |
# | `metadata` | `dict[str, Any]` | `field(default_factory=dict)` | no |
# | `record_payload` | `dict[str, Any] \| None` | `None` | no |

# %%
import inspect

if API is not None:
    try:
        print(inspect.signature(API))
    except (TypeError, ValueError):
        print('This public object has no callable signature.')
    summary = (getattr(API, '__doc__', None) or '').strip()
    print(summary.split('\n\n', 1)[0] if summary else 'No public docstring.')

# %% [markdown]
# ## Minimal public usage
#
# The example below stays on the public API surface.

# %%
RUN_EXAMPLE = False  # Set True after supplying the required constructor values.

if API is not None and RUN_EXAMPLE:
    value = API(...)  # Signature: GraphTensorView(node_features: np.ndarray, edge_index: np.ndarray, edge_features: np.ndarray | None = None, positions: np.ndarray | None = None, node_ids: list[str] = field(default_factory=list), node_type_ids: np.ndarray | None = None, edge_type_ids: np.ndarray | None = None, graph_features: np.ndarray | None = None, targets: dict[str, np.ndarray] = field(default_factory=dict), masks: dict[str, np.ndarray] = field(default_factory=dict), metadata: dict[str, Any] = field(default_factory=dict), record_payload: dict[str, Any] | None = None)
    print(value)

# %% [markdown]
# ## Expected behavior and common failures
#
# - `ValueError('node_features must have shape [N, F]')`
# - `ValueError('edge_index must have shape [2, E]')`
# - `ValueError('edge_index contains an invalid node index')`
# - `ValueError('edge_features rows must match edge count')`
# - `ValueError('positions must have shape [N, 3]')`
# - `ValueError('node_type_ids must have shape [N]')`
# - `ValueError('edge_type_ids must have shape [E]')`
#
# For dataset downloads, model training, molecular dynamics, and external engines, first test with a small input and an explicit output directory.
