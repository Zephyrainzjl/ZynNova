# %% [markdown]
# # `zynnova.structure.polymer.TransformerInputView`
#
# Public API notebook for **TransformerInputView**. This page only uses the supported public import path and intentionally omits internal implementation details.
#
# **Purpose:** Public dataclass `TransformerInputView`.

# %% [markdown]
# ## Installation
#
# Recommended installation for this API: `pip install 'zynnova[io]'`.
#
# Run this notebook from an environment where ZynNova is installed. Expensive downloads, training, visualization, and simulations are disabled by default.

# %%
try:
    from zynnova.structure.polymer import TransformerInputView as API
except ImportError as exc:
    API = None
    print('Optional dependency or installation is missing:', exc)
else:
    print('Imported: zynnova.structure.polymer.TransformerInputView')

# %% [markdown]
# ## Signature
#
# ```python
# TransformerInputView(tokens: list[str], token_type_ids: np.ndarray, attention_mask: np.ndarray, continuous_features: np.ndarray, continuous_feature_mask: np.ndarray, targets: dict[str, np.ndarray] = field(default_factory=dict), metadata: dict[str, Any] = field(default_factory=dict), record_payload: dict[str, Any] | None = None)
# ```
#
# | Parameter | Type | Default | Required |
# |---|---|---|---|
# | `tokens` | `list[str]` | `-` | yes |
# | `token_type_ids` | `np.ndarray` | `-` | yes |
# | `attention_mask` | `np.ndarray` | `-` | yes |
# | `continuous_features` | `np.ndarray` | `-` | yes |
# | `continuous_feature_mask` | `np.ndarray` | `-` | yes |
# | `targets` | `dict[str, np.ndarray]` | `field(default_factory=dict)` | no |
# | `metadata` | `dict[str, Any]` | `field(default_factory=dict)` | no |
# | `record_payload` | `dict[str, Any] \| None` | `None` | no |

# %%
import inspect

if API is not None:
    try:
        print(inspect.signature(API))
    except (TypeError, ValueError):
        print('This public object has no callable signature.')
    summary = (getattr(API, '__doc__', None) or '').strip()
    print(summary.split('\n\n', 1)[0] if summary else 'No public docstring.')

# %% [markdown]
# ## Minimal public usage
#
# The example below stays on the public API surface.

# %%
RUN_EXAMPLE = False  # Set True after supplying the required constructor values.

if API is not None and RUN_EXAMPLE:
    value = API(...)  # Signature: TransformerInputView(tokens: list[str], token_type_ids: np.ndarray, attention_mask: np.ndarray, continuous_features: np.ndarray, continuous_feature_mask: np.ndarray, targets: dict[str, np.ndarray] = field(default_factory=dict), metadata: dict[str, Any] = field(default_factory=dict), record_payload: dict[str, Any] | None = None)
    print(value)

# %% [markdown]
# ## Expected behavior and common failures
#
# - `ValueError('token arrays must match token count')`
# - `ValueError('continuous feature mask shape mismatch')`
#
# For dataset downloads, model training, molecular dynamics, and external engines, first test with a small input and an explicit output directory.
