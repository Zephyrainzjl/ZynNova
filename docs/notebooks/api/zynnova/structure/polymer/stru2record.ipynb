# %% [markdown]
# # `zynnova.structure.polymer.stru2record`
#
# Public API notebook for **stru2record**. This page only uses the supported public import path and intentionally omits internal implementation details.
#
# **Purpose:** Convert a real atomistic structure into the canonical PolymerRecord.

# %% [markdown]
# ## Installation
#
# Recommended installation for this API: `pip install 'zynnova[io]'`.
#
# Run this notebook from an environment where ZynNova is installed. Expensive downloads, training, visualization, and simulations are disabled by default.

# %%
try:
    from zynnova.structure.polymer import stru2record as API
except ImportError as exc:
    API = None
    print('Optional dependency or installation is missing:', exc)
else:
    print('Imported: zynnova.structure.polymer.stru2record')

# %% [markdown]
# ## Signature
#
# ```python
# stru2record(structure: Any, *, format: str | None = None, index: int | str = -1, record_id: str | None = None, atom_to_unit: Sequence[int | str] | np.ndarray | None = None, unit_atom_counts: Sequence[int] | None = None, unit_sequence: Sequence[str] | None = None, unit_library: Mapping[str, PolymerUnit | MolecularGraph | StructureData] | None = None, unit_roles: Mapping[str, UnitRole | str] | None = None, unit_ports: Mapping[str, Sequence[ConnectionPort]] | None = None, architecture_type: ArchitectureType | str = ArchitectureType.LINEAR, architecture_edges: Sequence[ArchitectureEdge | tuple[int, int] | tuple[str, str]] | None = None, state_id: str = 'structure', properties: Mapping[str, PropertyValue | float | int | list[float]] | None = None, ensemble: EnsembleStatistics | None = None, metadata: Mapping[str, Any] | None = None) -> PolymerRecord
# ```
#
# | Parameter | Type | Default | Required |
# |---|---|---|---|
# | `structure` | `Any` | `-` | yes |
# | `format` | `str \| None` | `None` | no |
# | `index` | `int \| str` | `-1` | no |
# | `record_id` | `str \| None` | `None` | no |
# | `atom_to_unit` | `Sequence[int \| str] \| np.ndarray \| None` | `None` | no |
# | `unit_atom_counts` | `Sequence[int] \| None` | `None` | no |
# | `unit_sequence` | `Sequence[str] \| None` | `None` | no |
# | `unit_library` | `Mapping[str, PolymerUnit \| MolecularGraph \| StructureData] \| None` | `None` | no |
# | `unit_roles` | `Mapping[str, UnitRole \| str] \| None` | `None` | no |
# | `unit_ports` | `Mapping[str, Sequence[ConnectionPort]] \| None` | `None` | no |
# | `architecture_type` | `ArchitectureType \| str` | `ArchitectureType.LINEAR` | no |
# | `architecture_edges` | `Sequence[ArchitectureEdge \| tuple[int, int] \| tuple[str, str]] \| None` | `None` | no |
# | `state_id` | `str` | `'structure'` | no |
# | `properties` | `Mapping[str, PropertyValue \| float \| int \| list[float]] \| None` | `None` | no |
# | `ensemble` | `EnsembleStatistics \| None` | `None` | no |
# | `metadata` | `Mapping[str, Any] \| None` | `None` | no |

# %%
import inspect

if API is not None:
    try:
        print(inspect.signature(API))
    except (TypeError, ValueError):
        print('This public object has no callable signature.')
    summary = (getattr(API, '__doc__', None) or '').strip()
    print(summary.split('\n\n', 1)[0] if summary else 'No public docstring.')

# %% [markdown]
# ## Minimal public usage
#
# The example below stays on the public API surface.

# %%
RUN_EXAMPLE = False  # Set True after replacing placeholders with your data.

if API is not None and RUN_EXAMPLE:
    result = API(...)  # Signature: stru2record(structure: Any, *, format: str | None = None, index: int | str = -1, record_id: str | None = None, atom_to_unit: Sequence[int | str] | np.ndarray | None = None, unit_atom_counts: Sequence[int] | None = None, unit_sequence: Sequence[str] | None = None, unit_library: Mapping[str, PolymerUnit | MolecularGraph | StructureData] | None = None, unit_roles: Mapping[str, UnitRole | str] | None = None, unit_ports: Mapping[str, Sequence[ConnectionPort]] | None = None, architecture_type: ArchitectureType | str = ArchitectureType.LINEAR, architecture_edges: Sequence[ArchitectureEdge | tuple[int, int] | tuple[str, str]] | None = None, state_id: str = 'structure', properties: Mapping[str, PropertyValue | float | int | list[float]] | None = None, ensemble: EnsembleStatistics | None = None, metadata: Mapping[str, Any] | None = None) -> PolymerRecord
    print(result)

# %% [markdown]
# ## Expected behavior and common failures
#
# - `ValueError('unit_sequence length must equal the number of unit occurrences')`
#
# For dataset downloads, model training, molecular dynamics, and external engines, first test with a small input and an explicit output directory.
