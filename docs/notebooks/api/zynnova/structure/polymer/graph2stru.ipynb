# %% [markdown]
# # `zynnova.structure.polymer.graph2stru`
#
# Public API notebook for **graph2stru**. This page only uses the supported public import path and intentionally omits internal implementation details.
#
# **Purpose:** Decode atom graphs, PyG objects, or polymer-specific training views.

# %% [markdown]
# ## Installation
#
# Recommended installation for this API: `pip install 'zynnova[io]'`.
#
# Run this notebook from an environment where ZynNova is installed. Expensive downloads, training, visualization, and simulations are disabled by default.

# %%
try:
    from zynnova.structure.polymer import graph2stru as API
except ImportError as exc:
    API = None
    print('Optional dependency or installation is missing:', exc)
else:
    print('Imported: zynnova.structure.polymer.graph2stru')

# %% [markdown]
# ## Signature
#
# ```python
# graph2stru(graph: Any, *, output: Literal['structure', 'ase'] = 'structure', include_edges_as_bonds: bool = True, path: str | Path | None = None, format: str | None = None, **decode_kwargs: Any) -> StructureData | Any
# ```
#
# | Parameter | Type | Default | Required |
# |---|---|---|---|
# | `graph` | `Any` | `-` | yes |
# | `output` | `Literal['structure', 'ase']` | `'structure'` | no |
# | `include_edges_as_bonds` | `bool` | `True` | no |
# | `path` | `str \| Path \| None` | `None` | no |
# | `format` | `str \| None` | `None` | no |
# | `**decode_kwargs` | `Any` | `-` | no |

# %%
import inspect

if API is not None:
    try:
        print(inspect.signature(API))
    except (TypeError, ValueError):
        print('This public object has no callable signature.')
    summary = (getattr(API, '__doc__', None) or '').strip()
    print(summary.split('\n\n', 1)[0] if summary else 'No public docstring.')

# %% [markdown]
# ## Minimal public usage
#
# The example below stays on the public API surface.

# %%
RUN_EXAMPLE = False  # Set True after replacing placeholders with your data.

if API is not None and RUN_EXAMPLE:
    result = API(...)  # Signature: graph2stru(graph: Any, *, output: Literal['structure', 'ase'] = 'structure', include_edges_as_bonds: bool = True, path: str | Path | None = None, format: str | None = None, **decode_kwargs: Any) -> StructureData | Any
    print(result)

# %% [markdown]
# ## Expected behavior and common failures
#
# - `ValueError("output must be 'structure' or 'ase'")`
#
# For dataset downloads, model training, molecular dynamics, and external engines, first test with a small input and an explicit output directory.
