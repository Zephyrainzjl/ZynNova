# %% [markdown]
# # `zynnova.structure.polymer.MolecularGraph`
#
# Public API notebook for **MolecularGraph**. This page only uses the supported public import path and intentionally omits internal implementation details.
#
# **Purpose:** A unit-level atom graph used by the polymer semantic layer.

# %% [markdown]
# ## Installation
#
# Recommended installation for this API: `pip install 'zynnova[io]'`.
#
# Run this notebook from an environment where ZynNova is installed. Expensive downloads, training, visualization, and simulations are disabled by default.

# %%
try:
    from zynnova.structure.polymer import MolecularGraph as API
except ImportError as exc:
    API = None
    print('Optional dependency or installation is missing:', exc)
else:
    print('Imported: zynnova.structure.polymer.MolecularGraph')

# %% [markdown]
# ## Signature
#
# ```python
# MolecularGraph(atoms: list[Atom], bonds: list[Bond], ports: list[ConnectionPort] = field(default_factory=list), coordinates: np.ndarray | None = None, metadata: dict[str, Any] = field(default_factory=dict))
# ```
#
# | Parameter | Type | Default | Required |
# |---|---|---|---|
# | `atoms` | `list[Atom]` | `-` | yes |
# | `bonds` | `list[Bond]` | `-` | yes |
# | `ports` | `list[ConnectionPort]` | `field(default_factory=list)` | no |
# | `coordinates` | `np.ndarray \| None` | `None` | no |
# | `metadata` | `dict[str, Any]` | `field(default_factory=dict)` | no |

# %%
import inspect

if API is not None:
    try:
        print(inspect.signature(API))
    except (TypeError, ValueError):
        print('This public object has no callable signature.')
    summary = (getattr(API, '__doc__', None) or '').strip()
    print(summary.split('\n\n', 1)[0] if summary else 'No public docstring.')

# %% [markdown]
# ## Minimal public usage
#
# The example below stays on the public API surface.

# %%
RUN_EXAMPLE = False  # Set True after supplying the required constructor values.

if API is not None and RUN_EXAMPLE:
    value = API(...)  # Signature: MolecularGraph(atoms: list[Atom], bonds: list[Bond], ports: list[ConnectionPort] = field(default_factory=list), coordinates: np.ndarray | None = None, metadata: dict[str, Any] = field(default_factory=dict))
    print(value)

# %% [markdown]
# ## Expected behavior and common failures
#
# - `KeyError(f'unknown port: {port_id}')`
# - `ValueError('molecular graph must contain at least one atom')`
# - `ValueError('atom_indices contains invalid indices')`
# - `ValueError('positions must have shape [num_atoms, 3]')`
# - `ValueError(f'duplicate port id: {port.id}')`
# - `ValueError(f'coordinates must have shape ({len(self.atoms)}, 3), got {array.shape}')`
#
# For dataset downloads, model training, molecular dynamics, and external engines, first test with a small input and an explicit output directory.
