# %% [markdown]
# # `zynnova.structure.polymer.Bond`
#
# Public API notebook for **Bond**. This page only uses the supported public import path and intentionally omits internal implementation details.
#
# **Purpose:** Public dataclass `Bond`.

# %% [markdown]
# ## Installation
#
# Recommended installation for this API: `pip install 'zynnova[io]'`.
#
# Run this notebook from an environment where ZynNova is installed. Expensive downloads, training, visualization, and simulations are disabled by default.

# %%
try:
    from zynnova.structure.polymer import Bond as API
except ImportError as exc:
    API = None
    print('Optional dependency or installation is missing:', exc)
else:
    print('Imported: zynnova.structure.polymer.Bond')

# %% [markdown]
# ## Signature
#
# ```python
# Bond(source: int, target: int, order: float = 1.0, aromatic: bool = False, conjugated: bool = False, stereo: str | None = None, kind: str = 'covalent', features: dict[str, Any] = field(default_factory=dict))
# ```
#
# | Parameter | Type | Default | Required |
# |---|---|---|---|
# | `source` | `int` | `-` | yes |
# | `target` | `int` | `-` | yes |
# | `order` | `float` | `1.0` | no |
# | `aromatic` | `bool` | `False` | no |
# | `conjugated` | `bool` | `False` | no |
# | `stereo` | `str \| None` | `None` | no |
# | `kind` | `str` | `'covalent'` | no |
# | `features` | `dict[str, Any]` | `field(default_factory=dict)` | no |

# %%
import inspect

if API is not None:
    try:
        print(inspect.signature(API))
    except (TypeError, ValueError):
        print('This public object has no callable signature.')
    summary = (getattr(API, '__doc__', None) or '').strip()
    print(summary.split('\n\n', 1)[0] if summary else 'No public docstring.')

# %% [markdown]
# ## Minimal public usage
#
# The example below stays on the public API surface.

# %%
RUN_EXAMPLE = False  # Set True after supplying the required constructor values.

if API is not None and RUN_EXAMPLE:
    value = API(...)  # Signature: Bond(source: int, target: int, order: float = 1.0, aromatic: bool = False, conjugated: bool = False, stereo: str | None = None, kind: str = 'covalent', features: dict[str, Any] = field(default_factory=dict))
    print(value)

# %% [markdown]
# ## Expected behavior and common failures
#
# - `ValueError('self-bond is not allowed')`
# - `IndexError('bond atom index out of range')`
# - `ValueError('bond order must be positive')`
#
# For dataset downloads, model training, molecular dynamics, and external engines, first test with a small input and an explicit output directory.
