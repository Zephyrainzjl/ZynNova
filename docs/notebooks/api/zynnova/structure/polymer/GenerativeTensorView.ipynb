# %% [markdown]
# # `zynnova.structure.polymer.GenerativeTensorView`
#
# Public API notebook for **GenerativeTensorView**. This page only uses the supported public import path and intentionally omits internal implementation details.
#
# **Purpose:** Dense mixed discrete/continuous representation for graph generation.

# %% [markdown]
# ## Installation
#
# Recommended installation for this API: `pip install 'zynnova[io]'`.
#
# Run this notebook from an environment where ZynNova is installed. Expensive downloads, training, visualization, and simulations are disabled by default.

# %%
try:
    from zynnova.structure.polymer import GenerativeTensorView as API
except ImportError as exc:
    API = None
    print('Optional dependency or installation is missing:', exc)
else:
    print('Imported: zynnova.structure.polymer.GenerativeTensorView')

# %% [markdown]
# ## Signature
#
# ```python
# GenerativeTensorView(level: Literal['unit', 'atom'], node_type: np.ndarray, node_mask: np.ndarray, node_features: np.ndarray, edge_type: np.ndarray, edge_mask: np.ndarray, composition_logits: np.ndarray, composition_mask: np.ndarray, transition_logits: np.ndarray, transition_mask: np.ndarray, continuous_features: np.ndarray, continuous_feature_mask: np.ndarray, coordinates: np.ndarray | None = None, coordinate_mask: np.ndarray | None = None, vocabularies: dict[str, dict[str, int]] = field(default_factory=dict), feature_names: list[str] = field(default_factory=list), metadata: dict[str, Any] = field(default_factory=dict), record_payload: dict[str, Any] | None = None)
# ```
#
# | Parameter | Type | Default | Required |
# |---|---|---|---|
# | `level` | `Literal['unit', 'atom']` | `-` | yes |
# | `node_type` | `np.ndarray` | `-` | yes |
# | `node_mask` | `np.ndarray` | `-` | yes |
# | `node_features` | `np.ndarray` | `-` | yes |
# | `edge_type` | `np.ndarray` | `-` | yes |
# | `edge_mask` | `np.ndarray` | `-` | yes |
# | `composition_logits` | `np.ndarray` | `-` | yes |
# | `composition_mask` | `np.ndarray` | `-` | yes |
# | `transition_logits` | `np.ndarray` | `-` | yes |
# | `transition_mask` | `np.ndarray` | `-` | yes |
# | `continuous_features` | `np.ndarray` | `-` | yes |
# | `continuous_feature_mask` | `np.ndarray` | `-` | yes |
# | `coordinates` | `np.ndarray \| None` | `None` | no |
# | `coordinate_mask` | `np.ndarray \| None` | `None` | no |
# | `vocabularies` | `dict[str, dict[str, int]]` | `field(default_factory=dict)` | no |
# | `feature_names` | `list[str]` | `field(default_factory=list)` | no |
# | `metadata` | `dict[str, Any]` | `field(default_factory=dict)` | no |
# | `record_payload` | `dict[str, Any] \| None` | `None` | no |

# %%
import inspect

if API is not None:
    try:
        print(inspect.signature(API))
    except (TypeError, ValueError):
        print('This public object has no callable signature.')
    summary = (getattr(API, '__doc__', None) or '').strip()
    print(summary.split('\n\n', 1)[0] if summary else 'No public docstring.')

# %% [markdown]
# ## Minimal public usage
#
# The example below stays on the public API surface.

# %%
RUN_EXAMPLE = False  # Set True after supplying the required constructor values.

if API is not None and RUN_EXAMPLE:
    value = API(...)  # Signature: GenerativeTensorView(level: Literal['unit', 'atom'], node_type: np.ndarray, node_mask: np.ndarray, node_features: np.ndarray, edge_type: np.ndarray, edge_mask: np.ndarray, composition_logits: np.ndarray, composition_mask: np.ndarray, transition_logits: np.ndarray, transition_mask: np.ndarray, continuous_features: np.ndarray, continuous_feature_mask: np.ndarray, coordinates: np.ndarray | None = None, coordinate_mask: np.ndarray | None = None, vocabularies: dict[str, dict[str, int]] = field(default_factory=dict), feature_names: list[str] = field(default_factory=list), metadata: dict[str, Any] = field(default_factory=dict), record_payload: dict[str, Any] | None = None)
    print(value)

# %% [markdown]
# ## Expected behavior and common failures
#
# - `ValueError('node_mask shape mismatch')`
# - `ValueError('node feature count mismatch')`
# - `ValueError('edge tensors must have shape [N, N]')`
# - `ValueError('composition_mask shape mismatch')`
# - `ValueError('transition_logits must have shape [K, K]')`
# - `ValueError('transition_mask must have shape [K, K]')`
# - `ValueError('coordinates must have shape [N, 3]')`
# - `ValueError('coordinate_mask required when coordinates are present')`
#
# For dataset downloads, model training, molecular dynamics, and external engines, first test with a small input and an explicit output directory.
